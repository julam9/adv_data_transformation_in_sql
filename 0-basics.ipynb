# %% [markdown]
# Connect to DuckDB

# %%
# Load the extension
# %load_ext sql
# Out:
# There's a new jupysql version available (0.10.14), you're running 0.10.12. To upgrade: pip install jupysql --upgrade
# Deploy Dash apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup

# %%
# Connect to DuckDB
# %sql duckdb:///tpch.db
# Out:
# Connecting to 'duckdb:///tpch.db'

# %%
# %config SqlMagic.displaylimit = 100

# %%
# %%sql
# -- Run a simple show tables
# SELECT
#   table_name
# FROM
#   information_schema.tables
# WHERE
#   table_schema = 'main'
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+
# | table_name |
# +------------+
# |  customer  |
# |  lineitem  |
# |   nation   |
# |   orders   |
# |    part    |
# |  partsupp  |
# |   region   |
# |  supplier  |
# +------------+

# %%
# If you do not see any tables run the below command (after uncommeting it)
#! python setup.py

# %% [markdown]
# # [GET DATA] Use SELECT...FROM, LIMIT, WHERE, & ORDER BY to read the required data from tables
#
# The most common use for querying is to read data in our tables. We can do this using a `SELECT ... FROM` statement, as shown below.

# %%
# %%sql
# SELECT
#   *
# FROM
#   customer
# LIMIT
#   1;
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+-------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------+
# | c_custkey |       c_name       |     c_address     | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                           c_comment                            |
# +-----------+--------------------+-------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------+
# |     1     | Customer#000000001 | j5JsirBM9PsCy0O1m |      15     | 25-989-741-2988 |   711.56  |   BUILDING   | y final requests wake slyly quickly special accounts. blithely |
# +-----------+--------------------+-------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------+

# %%
# %%sql
# -- use * to specify all columns
# SELECT
#   *
# FROM
#   orders
# LIMIT
#   5;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+---------------------------------------------------------------------------+
# | o_orderkey | o_custkey | o_orderstatus | o_totalprice | o_orderdate | o_orderpriority |     o_clerk     | o_shippriority |                                 o_comment                                 |
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+---------------------------------------------------------------------------+
# |     1      |   36901   |       O       |  173665.47   |  1996-01-02 |      5-LOW      | Clerk#000000951 |       0        |                     ly express platelets. deposits acc                    |
# |     2      |   78002   |       O       |   46929.18   |  1996-12-01 |     1-URGENT    | Clerk#000000880 |       0        |          ve the furiously fluffy dependencies. carefully regular          |
# |     3      |   123314  |       F       |  193846.25   |  1993-10-14 |      5-LOW      | Clerk#000000955 |       0        |  after the asymptotes. instructions cajole after the foxes. carefully unu |
# |     4      |   136777  |       O       |   32151.78   |  1995-10-11 |      5-LOW      | Clerk#000000124 |       0        |   st the furiously bold pinto beans. furiously pending theodolites cajol  |
# |     5      |   44485   |       F       |  144659.20   |  1994-07-30 |      5-LOW      | Clerk#000000925 |       0        |           onic requests. carefully daring foxes among the carefu          |
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+---------------------------------------------------------------------------+

# %% [markdown]
# However, running a `SELECT ... FROM` statement can cause issues when the data set is extensive.

# %%
# %%sql
# -- use * to specify all columns
# SELECT
#   *
# FROM
#   orders
# LIMIT
#   5;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+---------------------------------------------------------------------------+
# | o_orderkey | o_custkey | o_orderstatus | o_totalprice | o_orderdate | o_orderpriority |     o_clerk     | o_shippriority |                                 o_comment                                 |
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+---------------------------------------------------------------------------+
# |     1      |   36901   |       O       |  173665.47   |  1996-01-02 |      5-LOW      | Clerk#000000951 |       0        |                     ly express platelets. deposits acc                    |
# |     2      |   78002   |       O       |   46929.18   |  1996-12-01 |     1-URGENT    | Clerk#000000880 |       0        |          ve the furiously fluffy dependencies. carefully regular          |
# |     3      |   123314  |       F       |  193846.25   |  1993-10-14 |      5-LOW      | Clerk#000000955 |       0        |  after the asymptotes. instructions cajole after the foxes. carefully unu |
# |     4      |   136777  |       O       |   32151.78   |  1995-10-11 |      5-LOW      | Clerk#000000124 |       0        |   st the furiously bold pinto beans. furiously pending theodolites cajol  |
# |     5      |   44485   |       F       |  144659.20   |  1994-07-30 |      5-LOW      | Clerk#000000925 |       0        |           onic requests. carefully daring foxes among the carefu          |
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+---------------------------------------------------------------------------+

# %%
# %%sql
# -- use column c_names only to read data from those columns
# SELECT
#   o_orderkey,
#   o_totalprice
# FROM
#   orders
# LIMIT
#   5;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+--------------+
# | o_orderkey | o_totalprice |
# +------------+--------------+
# |     1      |  173665.47   |
# |     2      |   46929.18   |
# |     3      |  193846.25   |
# |     4      |   32151.78   |
# |     5      |  144659.20   |
# +------------+--------------+

# %% [markdown]
# We can use the `WHERE` clause if we want to get the rows that match specific criteria. We can specify one or more filters within the `WHERE` clause.
#
# The `WHERE` clause with more than one filter can use combinations of `AND` and `OR` criteria to combine the filter criteria, as shown below.

# %%
# %%sql
# -- all customer rows that have c_nationkey = 20
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_nationkey = 20
# LIMIT
#   10;
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                 | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                     c_comment                                                      |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+
# |     6     | Customer#000000006 |    g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E   |      20     | 30-114-968-4951 |  7638.57  |  AUTOMOBILE  |       quickly silent asymptotes are slyly regular excuses. instructions wake furiously? quickly bold courts p      |
# |     81    | Customer#000000081 |            9jUFbrThIIeoUNd8 9            |      20     | 30-165-277-3269 |  2023.71  |   BUILDING   |                 s against the ironic packages haggle carefully above the slyly express pinto beans                 |
# |    100    | Customer#000000100 |              MBy6qq3OEGpV4u              |      20     | 30-749-445-4907 |  9889.89  |  FURNITURE   |                   dazzle carefully furiously final foxes. express, ironic packages among the qui                   |
# |    210    | Customer#000000210 |          ,XOlfSzkZDAkm96adR41j,          |      20     | 30-876-248-9750 |  7250.14  |  HOUSEHOLD   |                                       es cajole bravely across the blithely                                        |
# |    223    | Customer#000000223 |          MyQxUcG0P QCetmG00GlF           |      20     | 30-193-643-1517 |  7476.20  |   BUILDING   |      xcuses. silent theodolites across the carefully bold excuses sleep ironic, final courts. regular excuses      |
# |    228    | Customer#000000228 | rZ1wxvHNByT71bUJWZjXMDROzlAch6FVu,dj8Zfq |      20     | 30-435-915-1603 |  6868.12  |  FURNITURE   |                                           es. blithely permanent sentim                                            |
# |    247    | Customer#000000247 |            eSAW4XaakYFj2WToKU            |      20     | 30-151-905-3513 |  8495.92  |  HOUSEHOLD   |                tes nag according to the blithe, even packages. sometimes unusual packages integrate                |
# |    278    | Customer#000000278 |             XHAfHlrYQM3elmhJ             |      20     | 30-445-570-5841 |  7621.56  |   BUILDING   | ely unusual accounts. stealthily special instructions affix blithely. regular, ironic packages sleep even platelet |
# |    285    | Customer#000000285 |   rB6fTQKle64k3MvCCatad8DfMgR5OZA G4r    |      20     | 30-235-130-1313 |  7276.72  |  FURNITURE   |         slyly according to the blithely special instructions. ironic ideas against the blithely furious pac        |
# |    321    | Customer#000000321 |     LX0SKs3jqo9wH1yixIdGWp2ItclDiuL      |      20     | 30-114-675-9153 |  7718.77  |  FURNITURE   |                ng the final, bold requests. furiously regular accounts inside the furiously pending                |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# -- all customer rows that have c_nationkey = 20 and c_acctbal > 1000
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_nationkey = 20
#   AND c_acctbal > 1000
# LIMIT
#   10;
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                 | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                     c_comment                                                      |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+
# |     6     | Customer#000000006 |    g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E   |      20     | 30-114-968-4951 |  7638.57  |  AUTOMOBILE  |       quickly silent asymptotes are slyly regular excuses. instructions wake furiously? quickly bold courts p      |
# |     81    | Customer#000000081 |            9jUFbrThIIeoUNd8 9            |      20     | 30-165-277-3269 |  2023.71  |   BUILDING   |                 s against the ironic packages haggle carefully above the slyly express pinto beans                 |
# |    100    | Customer#000000100 |              MBy6qq3OEGpV4u              |      20     | 30-749-445-4907 |  9889.89  |  FURNITURE   |                   dazzle carefully furiously final foxes. express, ironic packages among the qui                   |
# |    210    | Customer#000000210 |          ,XOlfSzkZDAkm96adR41j,          |      20     | 30-876-248-9750 |  7250.14  |  HOUSEHOLD   |                                       es cajole bravely across the blithely                                        |
# |    223    | Customer#000000223 |          MyQxUcG0P QCetmG00GlF           |      20     | 30-193-643-1517 |  7476.20  |   BUILDING   |      xcuses. silent theodolites across the carefully bold excuses sleep ironic, final courts. regular excuses      |
# |    228    | Customer#000000228 | rZ1wxvHNByT71bUJWZjXMDROzlAch6FVu,dj8Zfq |      20     | 30-435-915-1603 |  6868.12  |  FURNITURE   |                                           es. blithely permanent sentim                                            |
# |    247    | Customer#000000247 |            eSAW4XaakYFj2WToKU            |      20     | 30-151-905-3513 |  8495.92  |  HOUSEHOLD   |                tes nag according to the blithe, even packages. sometimes unusual packages integrate                |
# |    278    | Customer#000000278 |             XHAfHlrYQM3elmhJ             |      20     | 30-445-570-5841 |  7621.56  |   BUILDING   | ely unusual accounts. stealthily special instructions affix blithely. regular, ironic packages sleep even platelet |
# |    285    | Customer#000000285 |   rB6fTQKle64k3MvCCatad8DfMgR5OZA G4r    |      20     | 30-235-130-1313 |  7276.72  |  FURNITURE   |         slyly according to the blithely special instructions. ironic ideas against the blithely furious pac        |
# |    321    | Customer#000000321 |     LX0SKs3jqo9wH1yixIdGWp2ItclDiuL      |      20     | 30-114-675-9153 |  7718.77  |  FURNITURE   |                ng the final, bold requests. furiously regular accounts inside the furiously pending                |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# -- all customer rows that have c_nationkey = 20 or c_acctbal > 1000
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_nationkey = 20
#   OR c_acctbal > 1000
# LIMIT
#   10;
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                 | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                     c_comment                                                      |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+
# |     6     | Customer#000000006 |    g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E   |      20     | 30-114-968-4951 |  7638.57  |  AUTOMOBILE  |       quickly silent asymptotes are slyly regular excuses. instructions wake furiously? quickly bold courts p      |
# |     81    | Customer#000000081 |            9jUFbrThIIeoUNd8 9            |      20     | 30-165-277-3269 |  2023.71  |   BUILDING   |                 s against the ironic packages haggle carefully above the slyly express pinto beans                 |
# |    100    | Customer#000000100 |              MBy6qq3OEGpV4u              |      20     | 30-749-445-4907 |  9889.89  |  FURNITURE   |                   dazzle carefully furiously final foxes. express, ironic packages among the qui                   |
# |    210    | Customer#000000210 |          ,XOlfSzkZDAkm96adR41j,          |      20     | 30-876-248-9750 |  7250.14  |  HOUSEHOLD   |                                       es cajole bravely across the blithely                                        |
# |    223    | Customer#000000223 |          MyQxUcG0P QCetmG00GlF           |      20     | 30-193-643-1517 |  7476.20  |   BUILDING   |      xcuses. silent theodolites across the carefully bold excuses sleep ironic, final courts. regular excuses      |
# |    228    | Customer#000000228 | rZ1wxvHNByT71bUJWZjXMDROzlAch6FVu,dj8Zfq |      20     | 30-435-915-1603 |  6868.12  |  FURNITURE   |                                           es. blithely permanent sentim                                            |
# |    247    | Customer#000000247 |            eSAW4XaakYFj2WToKU            |      20     | 30-151-905-3513 |  8495.92  |  HOUSEHOLD   |                tes nag according to the blithe, even packages. sometimes unusual packages integrate                |
# |    278    | Customer#000000278 |             XHAfHlrYQM3elmhJ             |      20     | 30-445-570-5841 |  7621.56  |   BUILDING   | ely unusual accounts. stealthily special instructions affix blithely. regular, ironic packages sleep even platelet |
# |    285    | Customer#000000285 |   rB6fTQKle64k3MvCCatad8DfMgR5OZA G4r    |      20     | 30-235-130-1313 |  7276.72  |  FURNITURE   |         slyly according to the blithely special instructions. ironic ideas against the blithely furious pac        |
# |    321    | Customer#000000321 |     LX0SKs3jqo9wH1yixIdGWp2ItclDiuL      |      20     | 30-114-675-9153 |  7718.77  |  FURNITURE   |                ng the final, bold requests. furiously regular accounts inside the furiously pending                |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+--------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# -- all customer rows that have (c_nationkey = 20 and c_acctbal > 1000) or rows that have c_nationkey = 11
# SELECT
#   *
# FROM
#   customer
# WHERE
#   (
#     c_nationkey = 20
#     AND c_acctbal > 1000
#   )
#   OR c_nationkey = 11
# LIMIT
#   10;
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                 | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                c_comment                                                |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------+
# |     52    | Customer#000000052 |       UracAlAA8tSHL5V,poTZIOjh8o,        |      11     | 21-186-284-5998 |  5630.28  |  HOUSEHOLD   |                ts boost. carefully express waters across the blithely regular foxes inte                |
# |     84    | Customer#000000084 |   GB3sUmv RRXV DPzeOSbGxMIF9Z4Eq9 rop    |      11     | 21-546-818-3802 |  5174.71  |  FURNITURE   |          ounts. blithely express theodolites nag carefully ironic pinto beans. carefully final          |
# |    131    | Customer#000000131 |      ItdUFrHPZlzjZ, fo03sG4topAKTV       |      11     | 21-840-210-3572 |  8595.53  |  HOUSEHOLD   |              ly final Tiresias. slyly permanent theodolites cajole quickly. carefully unus              |
# |    134    | Customer#000000134 |        6I1TTaoG7bbiogCqRcptG6BYme        |      11     | 21-200-159-5932 |  4608.90  |   BUILDING   |                                  ly regular dolphins haggle blithely.                                   |
# |    148    | Customer#000000148 |          qJ8bFn4kwiit7RzwGrwo5m          |      11     | 21-562-498-6636 |  2135.60  |  HOUSEHOLD   | e carefully pending ideas detect slyly along the furiously special excuses. instructions use carefully  |
# |    190    | Customer#000000190 | mY30kK8AfsTGrx,L4zI   QlQnnmCUxikyc8QcZ7 |      11     | 21-730-373-8193 |  1657.46  |  AUTOMOBILE  |                                y even packages engage furiously pending p                               |
# |    219    | Customer#000000219 | N7HIf0,MtChIqMY5aCsXnBbKYGw8fMdxY3Ywtug  |      11     | 21-159-138-6090 |  9858.57  |  AUTOMOBILE  |                                      carefully pending instructions                                     |
# |    264    | Customer#000000264 |              ZWqGIvPWJAC9n               |      11     | 21-881-683-3829 |  3195.83  |  MACHINERY   |                                     egular dependencies wake reques                                     |
# |    280    | Customer#000000280 |              YLnIkFdUWmE,MI              |      11     | 21-537-461-3965 |  3952.84  |   BUILDING   |      yly quickly ruthless accounts. unusual deposits solve furiously across the requests. carefull      |
# |    292    | Customer#000000292 |              Ko3JXxuoWxIMR               |      11     | 21-457-910-2923 |  2975.43  |  HOUSEHOLD   |   ecial foxes play carefully silent deposits. quickly regular packages need to nag according to the th  |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------+

# %% [markdown]
# We can combine multiple filter clauses, as seen above. We have seen examples of equals (`=`) and greater than (`>`) conditional operators. There are 6 **conditional operators**, they are
#
# 1. **<** Less than
# 2. **>** Greater than
# 3. **<=** Less than or equal to
# 4. **>=** Greater than or equal to
# 5. **=** Equal
# 6. **<>** and **!=** both represent Not equal (some DBs only support one of these)
#
# Additionally, for string types, we can make **pattern matching with `like` condition**. In a `like` condition, a `_` means any single character, and `%` means zero or more characters, for example.

# %%
# %%sql
# -- all customer rows where the c_name has a 381 in it
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_name LIKE '%381%';
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                 | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                      c_comment                                                      |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------------------+
# |    381    | Customer#000000381 |             wXs5zN2nPHqPsfFO             |      5      | 15-860-208-7093 |  9931.71  |   BUILDING   |                           ithely along the regular, regular theodolites. fluffily pending                           |
# |    1381   | Customer#000001381 |  kAgLl7nUiPStCleWOiKevH3QAOhqtg9dVvrdN   |      22     | 32-418-900-6494 |   367.82  |   BUILDING   |                                      posits sleep carefully around the slyly e                                      |
# |    2381   | Customer#000002381 | z7B43DZ7RGlkgEi3YaXfy,Aw2SZepYurvII41Do  |      5      | 15-493-990-8133 |   412.99  |  FURNITURE   |                              ul requests use slyly quickly even deposits. slyly pending                             |
# |    3381   | Customer#000003381 |          03jULkpVTm92eKW24meIj           |      13     | 23-441-750-5088 |  2473.54  |  AUTOMOBILE  |                          er the carefully bold multipliers doze blithely along the furiousl                         |
# |    3810   | Customer#000003810 |            hlRTIO4e4HNahc8A D            |      18     | 28-881-994-8196 |  9906.80  |  FURNITURE   |                                           bold requests after the furiousl                                          |
# |    3811   | Customer#000003811 |           b6vEJqifAgSbGhzTwTz            |      22     | 32-962-997-2221 |  5697.04  |  FURNITURE   |                          he carefully special packages. regular deposits sleep blithely bl                          |
# |    3812   | Customer#000003812 |                HGYp5dZtlA                |      14     | 24-653-654-5032 |  4204.53  |  FURNITURE   |                                          y ironic requests believe blithely                                         |
# |    3813   | Customer#000003813 |      Aeky0En0JO5V1zRgFZ9EvCcBWaTmW       |      6      | 16-983-191-7833 |  -494.03  |  HOUSEHOLD   |                                   rding to the express foxes. bold platelets main                                   |
# |    3814   | Customer#000003814 |       FQ3lWCA3znooc3S SmDCfwqdn4R9       |      20     | 30-833-732-5401 |  -207.83  |  AUTOMOBILE  |                                        ounts alongside of the fluffily pendin                                       |
# |    3815   | Customer#000003815 |          S5SIUeDCuVOKRTZqZ5M4CC          |      19     | 29-968-870-7672 |  2887.99  |  FURNITURE   |                                     ccounts. fluffily bold requests sleep furio                                     |
# |    3816   | Customer#000003816 |                kFLu9DYSXH                |      6      | 16-806-750-3968 |  4353.05  |  AUTOMOBILE  |                 g the carefully ironic asymptotes. furiously ironic foxes haggle. fluffily bold pack                |
# |    3817   | Customer#000003817 |  IWp4rgxgRxvUeHK2xtX8SEfGYmHYrCCpbBwXm   |      16     | 26-142-669-5787 |  9766.42  |  AUTOMOBILE  |                       es until the bold instructions wake quickly carefully unusual packages;                       |
# |    3818   | Customer#000003818 | yrvC8HiUJVCsu7MyFHcyTcmAP0NgEWnoXQgTAz36 |      7      | 17-983-218-3716 |   346.99  |  AUTOMOBILE  |               theodolites. special instructions are blithely slyly special pinto beans; unusual, bold               |
# |    3819   | Customer#000003819 |              TejxSl9G1aF1x               |      4      | 14-964-709-5782 |  -210.31  |   BUILDING   |   os. excuses boost quickly across the carefully bold deposits. permanently pending accounts cajole. silent, clos   |
# |    4381   | Customer#000004381 |       MIQXH5W6Zsup5cVYfCtWupiJtgi        |      2      | 12-570-797-1472 |  2542.55  |  HOUSEHOLD   |                                      r deposits. carefully even packages along                                      |
# |    5381   | Customer#000005381 |      bXQ,KuigJB1nASXN73PDwNOvXCIkp5      |      5      | 15-700-184-7619 |  4130.88  |  MACHINERY   |                                es. carefully ironic ideas sleep blithely about the i                                |
# |    6381   | Customer#000006381 |          BKfk07DtN45gg2w4mMUK1           |      7      | 17-877-502-9214 |  7346.88  |  HOUSEHOLD   |        inal asymptotes boost. bold, ironic requests are along the regular, special packages. pending account        |
# |    7381   | Customer#000007381 |    yq7RXRmclCUi6wJspelKaEWSJ  TfycLah    |      20     | 30-666-139-1602 |   73.39   |   BUILDING   | fluffily special requests are about the fluffily unusual foxes. final frets are slyly fluffily final deposits. even |
# |    8381   | Customer#000008381 |  7kbg8wegbgGmgiW8OQ4SbJ8colXl6rpBmHudJ   |      0      | 10-177-308-9094 |  6674.59  |  AUTOMOBILE  |      uests against the carefully bold excuses sleep blithely slyly final instructions; unusual requests about       |
# |    9381   | Customer#000009381 |              BhXODcEOpwNg6               |      17     | 27-708-588-6706 |  4788.15  |  HOUSEHOLD   |            sual hockey players use above the final packages. quickly ironic excuses sleep. slyly final pa           |
# |   10381   | Customer#000010381 |               RLDSr5JOMK45               |      15     | 25-294-314-6077 |   106.15  |  FURNITURE   |                            r the furiously unusual pinto beans. blithely ironic pinto be                            |
# |   11381   | Customer#000011381 |             cHcQKKDGnWLbq48O             |      7      | 17-652-294-7849 |  1959.81  |  MACHINERY   |                                   structions. slyly ironic requests play furiously                                  |
# |   12381   | Customer#000012381 |     hPUYchVeqkeLC1QCsGJXF5Fj6QDQhkd      |      13     | 23-989-969-2819 |  1172.56  |  HOUSEHOLD   |                              cies cajole carefully. unusual, ironic ideas believe caref                             |
# |   13381   | Customer#000013381 |             TkAwDfheF4H3g9H              |      9      | 19-465-107-1496 |  3221.83  |  HOUSEHOLD   |               efully regular foxes. ironic platelets sleep above the regular deposits. furiously slow               |
# |   13810   | Customer#000013810 |      KDptBRwrSNgIfqVU,Si2smGKFLFix       |      18     | 28-953-486-1222 |  5133.48  |   BUILDING   |                          lithely. slyly ironic pinto beans nag. ironic, regular packages a                          |
# |   13811   | Customer#000013811 |       XvajiqJbFBaY8IfkIPanJeDnrba        |      19     | 29-964-589-6640 |  3436.54  |  MACHINERY   |                              ly regular theodolites: courts nag blithely. bold request                              |
# |   13812   | Customer#000013812 | WuM0MP,N22TPjuHnUzDbcyJF86fkycoa8L7xPsKK |      0      | 10-571-845-2630 |  5982.87  |  AUTOMOBILE  |                             lar ideas use carefully alongside of the fluffily final plat                            |
# |   13813   | Customer#000013813 |             Xh5saiXGJkv5 lL              |      21     | 31-140-142-6191 |  1190.11  |  MACHINERY   |            te blithely even instructions. regular, final orbits nag carefully. carefully bold dinos wake            |
# |   13814   | Customer#000013814 |         PnsbC4EN7J4TZ30 yPPlI8xh         |      17     | 27-767-457-2550 |  2131.39  |  FURNITURE   |                               instructions according to the furious, ironic platelets                               |
# |   13815   | Customer#000013815 |            UHXyxzMMNwV dIRAGo            |      11     | 21-606-813-1389 |  4240.37  |  FURNITURE   |                          special deposits. carefully daring requests sleep blithely. caref                          |
# |   13816   | Customer#000013816 |         XX Nlht,5lD6vroOC75qAS           |      17     | 27-501-367-6604 |  7844.29  |  AUTOMOBILE  |                              ully final excuses. carefully unusual accounts about the w                             |
# |   13817   | Customer#000013817 |      eg1g5BqcUMPqvGy9oY7bjVe7nj6NsH      |      3      | 13-978-449-6295 |  2094.32  |  FURNITURE   |                           slyly. even theodolites nag regularly-- furiously even foxes abo                          |
# |   13818   | Customer#000013818 |       r17Nf8Y8iLfBKIGP6zJUrWl5K3g        |      15     | 25-948-173-6359 |  8239.56  |  HOUSEHOLD   |                                 cial courts. excuses sleep quickly regular accounts.                                |
# |   13819   | Customer#000013819 | 9MlFsiIsVNrVT8jJKRp30wISV5sNdXAwIT85F8S  |      12     | 22-868-584-6588 |  1312.29  |   BUILDING   |                                        ackages. carefully special pinto beans                                       |
# |   14381   | Customer#000014381 |              jakuN8Gt0SJNE               |      21     | 31-449-680-6297 |  1915.30  |  FURNITURE   |              the even accounts cajole blithely furiously express theodolites. slyly regular platelets ha            |
# |   15381   | Customer#000015381 |             0WDBnrIu4 tnGsk              |      2      | 12-803-829-9591 |  4603.90  |  AUTOMOBILE  |                          ourts cajole across the never final foxes. furiously final pinto                           |
# |   16381   | Customer#000016381 |       p3OtEjK0ag1b78QVzxjATwtiFTD        |      1      | 11-916-158-3970 |  3394.31  |  AUTOMOBILE  |                                       en deposits haggle blithely special pac                                       |
# |   17381   | Customer#000017381 |      EPWFrLOY3DskysE6qBT4GCeJGUBl1       |      14     | 24-337-348-2161 |  1641.07  |  AUTOMOBILE  |                   onic dolphins. furiously even theodolites boost furiously. final, quiet requests                  |
# |   18381   | Customer#000018381 |         3 NvYjhsnClA31YiJ3kwgWK          |      11     | 21-536-361-3498 |  6912.76  |   BUILDING   |                                arefully bold deposits. blithely ironic requests cajol                               |
# |   19381   | Customer#000019381 | h9kcMiPeZocm4AZ0IyoTGep1Q,Ft81I83Dl6hAf8 |      22     | 32-222-471-6134 |  2796.19  |  AUTOMOBILE  |                       ctions. pinto beans are furiously quickly special instructions? ironic,                       |
# |   20381   | Customer#000020381 |              DOX0wniswpmaq               |      3      | 13-312-156-3988 |  4222.91  |  HOUSEHOLD   |     ts. slyly regular requests sleep furiously against the blithely final pains. bold, express deposits among t     |
# |   21381   | Customer#000021381 | ytmn2TjCb2Brk0T3bsQrfYrUJmeKsIYjzQlZ dcy |      0      | 10-382-890-9934 |  1206.06  |  HOUSEHOLD   |      en instructions. dependencies nag furiously. furiously ironic pinto beans haggle carefully; even accounts      |
# |   22381   | Customer#000022381 |        oIQ99IfxSR,y WICHwVRJEBw,         |      23     | 33-531-456-1432 |  9975.59  |  HOUSEHOLD   |                                        ording to the furiously bold accounts.                                       |
# |   23381   | Customer#000023381 |     1IN8qyqeWVCfr6naVwsofa96DIZxfAQ      |      6      | 16-849-335-4074 |  -677.08  |  FURNITURE   |                                furiously pending requests. slyly express deposits slee                              |
# |   23810   | Customer#000023810 | ,U1YyqqA,8iPUUMFckZs2A8FL3kRN8SMalxcFJ1Z |      7      | 17-160-708-7556 |  6278.23  |  HOUSEHOLD   |      ns along the final packages haggle busily pinto beans. carefully regular foxes affix carefully across the      |
# |   23811   | Customer#000023811 | R2AgnDyeL21XBV66Xs79FxG048DlBePFsUQ KNn  |      22     | 32-536-968-4006 |  4214.70  |  HOUSEHOLD   |            inal deposits sleep furiously! ideas across the blithely ironic packages use carefully ironic            |
# |   23812   | Customer#000023812 |      oxPJj6eEyHlDSRY0A3bkHfHozqPcb       |      11     | 21-353-601-1743 |  5472.91  |   BUILDING   |                                 es. furiously final foxes use slyly according to th                                 |
# |   23813   | Customer#000023813 | SxReloxThKD66i10QQ0SS3OSYtvX1899DPRYaVpR |      9      | 19-554-125-5133 |  -804.30  |  MACHINERY   |    refully regular foxes cajole carefully. quickly ironic packages cajole carefully ironic instructions. unusual    |
# |   23814   | Customer#000023814 |       mygAjACGptSxCd3qXJ7IqHVT9sSA       |      20     | 30-269-927-9821 |  -915.92  |  AUTOMOBILE  |  ar patterns sleep fluffily. slyly ironic pinto beans sleep evenly about the even deposits. blithely even asymptot  |
# |   23815   | Customer#000023815 |       LX1hkQaUm4fIa,nmKIkd2pJSVjoO       |      23     | 33-464-125-5917 |  3981.12  |  AUTOMOBILE  |                pending deposits detect pinto beans. slyly ironic packages breach blithely during the c              |
# |   23816   | Customer#000023816 |              jYzTnAURF6eMaS              |      10     | 20-856-131-1668 |  6674.49  |  HOUSEHOLD   |                   ithely express accounts are carefully across the even, pending pinto beans. qui                   |
# |   23817   | Customer#000023817 |        qajRn4BkyPxjrexA6A jH6zbG         |      20     | 30-904-602-2642 |  9144.81  |  FURNITURE   |                                    d excuses cajole ideas. bold packages should                                     |
# |   23818   | Customer#000023818 |               j l,tqVMTzu                |      4      | 14-471-660-4311 |  2866.35  |  FURNITURE   |         r pinto beans. evenly final foxes during the blithely regular deposits kindle about the even deposit        |
# |   23819   | Customer#000023819 | YpEyb9YwCSUWr,ETbe1ip7jPZ7SW7oL06UbXoMp  |      6      | 16-776-820-5272 |  3767.17  |  MACHINERY   |                             yly regular platelets x-ray blithely even packages. sly, reg                            |
# |   24381   | Customer#000024381 |            rC3CNibCBJA35VtUBK            |      11     | 21-815-816-3231 |  7117.97  |  FURNITURE   |                                           ly regular requests. blithely bo                                          |
# |   25381   | Customer#000025381 | xSSmp8KkE5LHA4CI4e8BXmTCT2uj1MN3QvdtuRB  |      18     | 28-756-528-3414 |   924.75  |  MACHINERY   |                    ic deposits boost fluffily furiously final accounts. bold packages boost. pend                   |
# |   26381   | Customer#000026381 |            BLRLOmQkXypK73gtN             |      15     | 25-891-343-9696 |  8037.93  |  FURNITURE   |                                y. busy requests boost never ironic pinto beans. quick                               |
# |   27381   | Customer#000027381 |            j5YiOPEWBRJ6zWE3L             |      23     | 33-689-555-1103 |  -626.93  |  FURNITURE   |                                        yly special deposits nag carefully re                                        |
# |   28381   | Customer#000028381 |        OK,Q F5ySvhtZoLX1WUJNjWXH,        |      6      | 16-573-275-9133 |  1528.84  |  FURNITURE   |                  enticingly special platelets nag slyly among the slyly pending accounts. quickly                   |
# |   29381   | Customer#000029381 |                oBxNmGqClJ                |      21     | 31-927-733-3726 |  2966.88  |  MACHINERY   |                                            ular excuses. fluffily even i                                            |
# |   30381   | Customer#000030381 |             atdVtLIBzxpwWbd              |      5      | 15-112-185-3081 |  -474.25  |  FURNITURE   |                                    s. furiously final ideas maintain quickly acr                                    |
# |   31381   | Customer#000031381 |   7P5SUhkWnN0CaqEg9bomYUHmBakFFjKUleDu   |      9      | 19-641-760-2057 |  5021.57  |  AUTOMOBILE  |                                    to beans after the requests eat about the slyl                                   |
# |   32381   | Customer#000032381 |             vPGBYhSAYUAboyt              |      2      | 12-864-275-1543 |  6086.68  |  FURNITURE   |             ts. carefully ruthless requests will sleep slyly. carefully ironic asymptotes promise slyly             |
# |   33381   | Customer#000033381 |     Hx3u8cW3LcuBHmxIkGqfmocCBWbg ZkO     |      24     | 34-730-362-3607 |  9662.32  |  AUTOMOBILE  |                      ke slyly dolphins. quickly regular dependencies haggle ironically. bold d                      |
# |   33810   | Customer#000033810 |        1XUEE401JWYkU8M,3K6nN40MEt        |      17     | 27-812-709-1065 |   133.17  |   BUILDING   |                    c accounts nag. even deposits are. carefully ironic instructions sleep perman                    |
# |   33811   | Customer#000033811 |    MVDjdaQwuwJnD,HldJ2Vb0NPwmfeS4HCxX    |      17     | 27-656-698-5586 |  3109.07  |  AUTOMOBILE  |                                ntegrate blithely unusual accounts. blithely ironic a                                |
# |   33812   | Customer#000033812 |             ZsJOoZjXGSlPzGPT             |      4      | 14-333-122-9311 |  2158.19  |  MACHINERY   |                                          osits sleep slyly even notornis.                                           |
# |   33813   | Customer#000033813 |       IgaNaRNF V4WfyOu4z3CqNGJknP2       |      1      | 11-905-626-8762 |  3602.45  |  FURNITURE   |                 ts nag. fluffily ironic packages haggle quickly after the slyly thin requests. slow                 |
# |   33814   | Customer#000033814 |   qRMag077EZPk3auS hKxKHCL5tRk9zM1E2Bd   |      17     | 27-282-956-8296 |   317.39  |  HOUSEHOLD   |       ully silent deposits. quickly regular packages need to nag according to the thinly silent accounts. pac       |
# |   33815   | Customer#000033815 |      4krT5wNMcAPY5CZ9zIfcBEC2N8 vV       |      14     | 24-766-140-8664 |  8319.72  |   BUILDING   |                                mptotes solve after the accounts. accounts sleep final                               |
# |   33816   | Customer#000033816 |              kUe6Ew7JMzUIP               |      11     | 21-425-404-8164 |  6574.49  |  HOUSEHOLD   |             express foxes sleep quickly bold, unusual excuses. slyly pending dependencies cajole blithe             |
# |   33817   | Customer#000033817 |           t2FWyEoIswzUyijd1UaG           |      12     | 22-922-251-4497 |   447.71  |  FURNITURE   |                quests hinder furiously even pinto beans. furiously idle epitaphs lose slyly. slyly re               |
# |   33818   | Customer#000033818 |         dm2bFs6mlTDmRuI,2Oj0lNm2         |      14     | 24-761-236-4572 |  9595.87  |  AUTOMOBILE  |                            the evenly final frets. blithely unusual excuses use slyly fur                           |
# |   33819   | Customer#000033819 |  3ZSW3dh9CwQK5O7injFU Ma3kohw2ckeODAIRR  |      11     | 21-802-682-4169 |  4814.46  |  AUTOMOBILE  |                                        e among the furiously regular foxes. f                                       |
# |   34381   | Customer#000034381 |          JQf75xd gNeXqlsFVXlYsE          |      2      | 12-822-913-8139 |  9125.06  |   BUILDING   |                    ithely after the regular deposits. evenly ironic instructions detect finally s                   |
# |   35381   | Customer#000035381 |              k0a4QnPrvmaNj               |      19     | 29-202-512-4850 |  6218.23  |  AUTOMOBILE  |                        uickly unusual packages across the blithely even accounts cajole quic                        |
# |   36381   | Customer#000036381 |          qUdriX3xuEYpkXc10JiPc           |      18     | 28-610-215-2977 |  5308.26  |  FURNITURE   |                                        gside of the quickly ironic accounts--                                       |
# |   37381   | Customer#000037381 |              GaJLp3nQG90HU9              |      6      | 16-990-619-1347 |   56.89   |   BUILDING   |    yly unusual requests boost fluffily ironic requests. quickly express requests according to the blithely expres   |
# |   38100   | Customer#000038100 |            pNJiCRjPXCSr8dkhQ             |      0      | 10-500-721-9562 |  7609.86  |  FURNITURE   |                         ss the fluffily ironic tithes. regular requests cajole slyly. daring                        |
# |   38101   | Customer#000038101 |        130ZvcYoZiy4KbZB,iRWXeXQKI        |      9      | 19-971-661-4000 |   -42.14  |  FURNITURE   |                                       press forges affix slyly: express depen                                       |
# |   38102   | Customer#000038102 |                VvY8kmc8euZ               |      6      | 16-253-756-4434 |  4724.66  |  MACHINERY   |         the furiously unusual accounts. regular, pending requests use carefully. furiously bold depths x-ray.       |
# |   38103   | Customer#000038103 |  iU0Ulbm5qKh75NF8pTs5nigtzLu6wnM2T5KuN   |      18     | 28-379-532-4625 |  7299.01  |  HOUSEHOLD   |                 requests would are furiously unusual accounts. blithely pending instructions wake sly               |
# |   38104   | Customer#000038104 |      ,mOvSgHqD02vqUQ6TeqTozJTLerf9       |      11     | 21-296-375-5262 |   522.88  |  HOUSEHOLD   |                                    sly special pinto beans poach along the ironi                                    |
# |   38105   | Customer#000038105 |   nDgaQ5tolp10Y8Z66hbxJloRlRfLMWRGkQ6e   |      21     | 31-719-896-9971 |  8050.86  |  FURNITURE   |           al accounts. blithely final foxes among the carefully final accounts nag among the slyly even f           |
# |   38106   | Customer#000038106 |             mYmy FFaWVNSbJ7              |      2      | 12-228-103-5411 |  8879.84  |   BUILDING   |                                    xes. regularly ironic packages should have to                                    |
# |   38107   | Customer#000038107 |      op lyoS69eDsTEUY5EBADBtM6hwalC      |      6      | 16-826-866-6588 |  4464.56  |  MACHINERY   |               ong the foxes. quickly regular accounts haggle slyly carefully pending sentiments. unus               |
# |   38108   | Customer#000038108 |      MQPGRZGl1Ys6hBGAuQkgIUOCrmrSJB      |      23     | 33-978-838-3842 |  2800.72  |  MACHINERY   |                ly regular dolphins. bold, special requests boost furiously bold deposits. slowly eve                |
# |   38109   | Customer#000038109 |        KZcZJ09L2hh5eLE19a2Rtk7QLa        |      3      | 13-729-549-8360 |   716.99  |  FURNITURE   |                                   foxes haggle ironically. thinly ironic requests                                   |
# |   38110   | Customer#000038110 |               9keh6mkb6lH8               |      15     | 25-293-774-3218 |  3476.20  |  AUTOMOBILE  |                               sly unusual pains about the blithely regular deposits na                              |
# |   38111   | Customer#000038111 |              oIsTWuPhW m1I               |      23     | 33-819-995-6660 |  1507.81  |  MACHINERY   |          counts. unusual courts above the blithely final requests sleep among the carefully special packag          |
# |   38112   | Customer#000038112 | GAIDtj,2sJaU,k780Wmr0IuwwHtXuMlOpoQkYSv  |      14     | 24-281-499-8893 |  6642.61  |  MACHINERY   |                ns haggle furiously ironic accounts. ironic theodolites against the stealthy accounts                |
# |   38113   | Customer#000038113 |      gKtIUtcCsixUSTn7VxvoPUA102aO8       |      9      | 19-511-491-3053 |  1302.02  |  MACHINERY   |                  ven instructions against the blithely regular foxes kindle multipliers. bold cour                  |
# |   38114   | Customer#000038114 | gdi4n4km9B0TM2xNbFSwdZZBT4X2z5P9GoRhBvH  |      23     | 33-358-241-2384 |  1992.80  |   BUILDING   |             lar epitaphs sleep carefully furiously final dependencies! blithely final instructions sleep            |
# |   38115   | Customer#000038115 |                SiP zwN5xp                |      17     | 27-448-164-2458 |  6916.80  |  HOUSEHOLD   |                                          ites detect. furiously ironic req                                          |
# |   38116   | Customer#000038116 |                7S12AfrLRS                |      0      | 10-758-227-7794 |   676.69  |  FURNITURE   |                       ily special foxes. fluffily regular requests haggle slyly regular pinto                       |
# |   38117   | Customer#000038117 |            Gc2EAJ0h0WpHnO2,u             |      21     | 31-196-336-9343 |  8028.94  |   BUILDING   |  s among the slow dolphins cajole slyly blithely even somas. idly ironic requests according to the blithely ironic  |
# |   38118   | Customer#000038118 |       4LChlpp1u6w1O0RkEgnbwqhk9Cs6       |      2      | 12-234-677-9655 |  3417.39  |  MACHINERY   |                                       sts hinder along the special platelets.                                       |
# |   38119   | Customer#000038119 |             GZ8XbHB2quwJ0y8              |      18     | 28-107-350-4857 |  3040.83  |  MACHINERY   |  ts. final dolphins cajole quickly fluffily final accounts. slyly pending accounts across the fluffily unusual idea |
# |   38120   | Customer#000038120 |       xUPLzuiIjGswgq47yR b0PSHVKCX       |      19     | 29-249-901-9332 |  -860.17  |  HOUSEHOLD   |                                           bold pinto beans sleep furiousl                                           |
# |   38121   | Customer#000038121 |            7PSSbWQnyYdnjzdJNN            |      6      | 16-205-879-4831 |  6086.33  |  FURNITURE   |   fully pending frays. quickly silent packages alongside of the blithely pending requests thrash above the careful  |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------------------+
# Truncated to displaylimit of 100.

# %%
# %%sql
# -- all customer rows where the c_name ends with a 381
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_name LIKE '%381';
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                 | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                      c_comment                                                      |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------------------+
# |    381    | Customer#000000381 |             wXs5zN2nPHqPsfFO             |      5      | 15-860-208-7093 |  9931.71  |   BUILDING   |                           ithely along the regular, regular theodolites. fluffily pending                           |
# |    1381   | Customer#000001381 |  kAgLl7nUiPStCleWOiKevH3QAOhqtg9dVvrdN   |      22     | 32-418-900-6494 |   367.82  |   BUILDING   |                                      posits sleep carefully around the slyly e                                      |
# |    2381   | Customer#000002381 | z7B43DZ7RGlkgEi3YaXfy,Aw2SZepYurvII41Do  |      5      | 15-493-990-8133 |   412.99  |  FURNITURE   |                              ul requests use slyly quickly even deposits. slyly pending                             |
# |    3381   | Customer#000003381 |          03jULkpVTm92eKW24meIj           |      13     | 23-441-750-5088 |  2473.54  |  AUTOMOBILE  |                          er the carefully bold multipliers doze blithely along the furiousl                         |
# |    4381   | Customer#000004381 |       MIQXH5W6Zsup5cVYfCtWupiJtgi        |      2      | 12-570-797-1472 |  2542.55  |  HOUSEHOLD   |                                      r deposits. carefully even packages along                                      |
# |    5381   | Customer#000005381 |      bXQ,KuigJB1nASXN73PDwNOvXCIkp5      |      5      | 15-700-184-7619 |  4130.88  |  MACHINERY   |                                es. carefully ironic ideas sleep blithely about the i                                |
# |    6381   | Customer#000006381 |          BKfk07DtN45gg2w4mMUK1           |      7      | 17-877-502-9214 |  7346.88  |  HOUSEHOLD   |        inal asymptotes boost. bold, ironic requests are along the regular, special packages. pending account        |
# |    7381   | Customer#000007381 |    yq7RXRmclCUi6wJspelKaEWSJ  TfycLah    |      20     | 30-666-139-1602 |   73.39   |   BUILDING   | fluffily special requests are about the fluffily unusual foxes. final frets are slyly fluffily final deposits. even |
# |    8381   | Customer#000008381 |  7kbg8wegbgGmgiW8OQ4SbJ8colXl6rpBmHudJ   |      0      | 10-177-308-9094 |  6674.59  |  AUTOMOBILE  |      uests against the carefully bold excuses sleep blithely slyly final instructions; unusual requests about       |
# |    9381   | Customer#000009381 |              BhXODcEOpwNg6               |      17     | 27-708-588-6706 |  4788.15  |  HOUSEHOLD   |            sual hockey players use above the final packages. quickly ironic excuses sleep. slyly final pa           |
# |   10381   | Customer#000010381 |               RLDSr5JOMK45               |      15     | 25-294-314-6077 |   106.15  |  FURNITURE   |                            r the furiously unusual pinto beans. blithely ironic pinto be                            |
# |   11381   | Customer#000011381 |             cHcQKKDGnWLbq48O             |      7      | 17-652-294-7849 |  1959.81  |  MACHINERY   |                                   structions. slyly ironic requests play furiously                                  |
# |   12381   | Customer#000012381 |     hPUYchVeqkeLC1QCsGJXF5Fj6QDQhkd      |      13     | 23-989-969-2819 |  1172.56  |  HOUSEHOLD   |                              cies cajole carefully. unusual, ironic ideas believe caref                             |
# |   13381   | Customer#000013381 |             TkAwDfheF4H3g9H              |      9      | 19-465-107-1496 |  3221.83  |  HOUSEHOLD   |               efully regular foxes. ironic platelets sleep above the regular deposits. furiously slow               |
# |   14381   | Customer#000014381 |              jakuN8Gt0SJNE               |      21     | 31-449-680-6297 |  1915.30  |  FURNITURE   |              the even accounts cajole blithely furiously express theodolites. slyly regular platelets ha            |
# |   15381   | Customer#000015381 |             0WDBnrIu4 tnGsk              |      2      | 12-803-829-9591 |  4603.90  |  AUTOMOBILE  |                          ourts cajole across the never final foxes. furiously final pinto                           |
# |   16381   | Customer#000016381 |       p3OtEjK0ag1b78QVzxjATwtiFTD        |      1      | 11-916-158-3970 |  3394.31  |  AUTOMOBILE  |                                       en deposits haggle blithely special pac                                       |
# |   17381   | Customer#000017381 |      EPWFrLOY3DskysE6qBT4GCeJGUBl1       |      14     | 24-337-348-2161 |  1641.07  |  AUTOMOBILE  |                   onic dolphins. furiously even theodolites boost furiously. final, quiet requests                  |
# |   18381   | Customer#000018381 |         3 NvYjhsnClA31YiJ3kwgWK          |      11     | 21-536-361-3498 |  6912.76  |   BUILDING   |                                arefully bold deposits. blithely ironic requests cajol                               |
# |   19381   | Customer#000019381 | h9kcMiPeZocm4AZ0IyoTGep1Q,Ft81I83Dl6hAf8 |      22     | 32-222-471-6134 |  2796.19  |  AUTOMOBILE  |                       ctions. pinto beans are furiously quickly special instructions? ironic,                       |
# |   20381   | Customer#000020381 |              DOX0wniswpmaq               |      3      | 13-312-156-3988 |  4222.91  |  HOUSEHOLD   |     ts. slyly regular requests sleep furiously against the blithely final pains. bold, express deposits among t     |
# |   21381   | Customer#000021381 | ytmn2TjCb2Brk0T3bsQrfYrUJmeKsIYjzQlZ dcy |      0      | 10-382-890-9934 |  1206.06  |  HOUSEHOLD   |      en instructions. dependencies nag furiously. furiously ironic pinto beans haggle carefully; even accounts      |
# |   22381   | Customer#000022381 |        oIQ99IfxSR,y WICHwVRJEBw,         |      23     | 33-531-456-1432 |  9975.59  |  HOUSEHOLD   |                                        ording to the furiously bold accounts.                                       |
# |   23381   | Customer#000023381 |     1IN8qyqeWVCfr6naVwsofa96DIZxfAQ      |      6      | 16-849-335-4074 |  -677.08  |  FURNITURE   |                                furiously pending requests. slyly express deposits slee                              |
# |   24381   | Customer#000024381 |            rC3CNibCBJA35VtUBK            |      11     | 21-815-816-3231 |  7117.97  |  FURNITURE   |                                           ly regular requests. blithely bo                                          |
# |   25381   | Customer#000025381 | xSSmp8KkE5LHA4CI4e8BXmTCT2uj1MN3QvdtuRB  |      18     | 28-756-528-3414 |   924.75  |  MACHINERY   |                    ic deposits boost fluffily furiously final accounts. bold packages boost. pend                   |
# |   26381   | Customer#000026381 |            BLRLOmQkXypK73gtN             |      15     | 25-891-343-9696 |  8037.93  |  FURNITURE   |                                y. busy requests boost never ironic pinto beans. quick                               |
# |   27381   | Customer#000027381 |            j5YiOPEWBRJ6zWE3L             |      23     | 33-689-555-1103 |  -626.93  |  FURNITURE   |                                        yly special deposits nag carefully re                                        |
# |   28381   | Customer#000028381 |        OK,Q F5ySvhtZoLX1WUJNjWXH,        |      6      | 16-573-275-9133 |  1528.84  |  FURNITURE   |                  enticingly special platelets nag slyly among the slyly pending accounts. quickly                   |
# |   29381   | Customer#000029381 |                oBxNmGqClJ                |      21     | 31-927-733-3726 |  2966.88  |  MACHINERY   |                                            ular excuses. fluffily even i                                            |
# |   30381   | Customer#000030381 |             atdVtLIBzxpwWbd              |      5      | 15-112-185-3081 |  -474.25  |  FURNITURE   |                                    s. furiously final ideas maintain quickly acr                                    |
# |   31381   | Customer#000031381 |   7P5SUhkWnN0CaqEg9bomYUHmBakFFjKUleDu   |      9      | 19-641-760-2057 |  5021.57  |  AUTOMOBILE  |                                    to beans after the requests eat about the slyl                                   |
# |   32381   | Customer#000032381 |             vPGBYhSAYUAboyt              |      2      | 12-864-275-1543 |  6086.68  |  FURNITURE   |             ts. carefully ruthless requests will sleep slyly. carefully ironic asymptotes promise slyly             |
# |   33381   | Customer#000033381 |     Hx3u8cW3LcuBHmxIkGqfmocCBWbg ZkO     |      24     | 34-730-362-3607 |  9662.32  |  AUTOMOBILE  |                      ke slyly dolphins. quickly regular dependencies haggle ironically. bold d                      |
# |   34381   | Customer#000034381 |          JQf75xd gNeXqlsFVXlYsE          |      2      | 12-822-913-8139 |  9125.06  |   BUILDING   |                    ithely after the regular deposits. evenly ironic instructions detect finally s                   |
# |   35381   | Customer#000035381 |              k0a4QnPrvmaNj               |      19     | 29-202-512-4850 |  6218.23  |  AUTOMOBILE  |                        uickly unusual packages across the blithely even accounts cajole quic                        |
# |   36381   | Customer#000036381 |          qUdriX3xuEYpkXc10JiPc           |      18     | 28-610-215-2977 |  5308.26  |  FURNITURE   |                                        gside of the quickly ironic accounts--                                       |
# |   37381   | Customer#000037381 |              GaJLp3nQG90HU9              |      6      | 16-990-619-1347 |   56.89   |   BUILDING   |    yly unusual requests boost fluffily ironic requests. quickly express requests according to the blithely expres   |
# |   38381   | Customer#000038381 |         2C4iaCmDTfF,bIwHMVDV7igz         |      21     | 31-401-857-5290 |  3613.51  |  FURNITURE   |       ts boost fluffily among the slyly unusual accounts. regular packages upon the ironic, final packages x-r      |
# |   39381   | Customer#000039381 |      4dt2W ej329klJLsGtvn UXF7GHLu       |      15     | 25-808-897-6249 |  1436.58  |  AUTOMOBILE  |            he even theodolites. ironic asymptotes are regularly bold deposits. final, regular escapades m           |
# |   40381   | Customer#000040381 |    QdCtT8dyADs6DUotpQh5wpKteb0ia UiHY    |      7      | 17-192-225-6461 |  5129.51  |  HOUSEHOLD   |                                      carefully regular packages. furiously unu                                      |
# |   41381   | Customer#000041381 |             aYk6ZOfcEKPW9fFE             |      6      | 16-663-305-3248 |  6681.02  |  FURNITURE   |                              regular gifts detect. carefully pending instructions are.                              |
# |   42381   | Customer#000042381 |               RWudFOWTRV8a               |      9      | 19-555-566-9019 |  9035.61  |  HOUSEHOLD   |                                    the slyly regular frets. unusual packages hang                                   |
# |   43381   | Customer#000043381 |            mK36s2P60W QdYosSK            |      7      | 17-357-100-1959 |  9637.59  |  FURNITURE   |             uriously ironic deposits. slyly express foxes wake furiously alongside of the pending packa             |
# |   44381   | Customer#000044381 | eU3aaGzE4oAynYH52YLCW3LGDJhpqUPXYz2f4Kx  |      10     | 20-115-458-7417 |  3062.59  |  MACHINERY   |                  sits. quickly regular asymptotes cajole fluffily across the furiously even request                 |
# |   45381   | Customer#000045381 |              d eLsVc61YxgE3              |      24     | 34-654-227-5617 |   252.63  |  MACHINERY   |                            nstructions. slyly final packages along the quickly regular pi                           |
# |   46381   | Customer#000046381 |        S5EYdte4NRnlOOl4WLIm26Cacu        |      17     | 27-470-410-9374 |  2995.66  |  AUTOMOBILE  |          re carefully after the blithely special requests. quickly special foxes affix carefully closely bo         |
# |   47381   | Customer#000047381 |   eHst2Alwp3xJ2Wuzr69zrcISFquqYalkCO5    |      20     | 30-477-315-4149 |  -561.43  |  AUTOMOBILE  |    along the fluffily unusual foxes. quiet packages impress fluffily. fluffily even warthogs affix furiously! acc   |
# |   48381   | Customer#000048381 |              4PIlc3z5Nq5zUe              |      12     | 22-623-196-5340 |  8814.36  |  MACHINERY   |                            sits about the furiously special packages cajole quickly accor                           |
# |   49381   | Customer#000049381 |       hhq644jJsK5 j2w4yFvYV9rq6wG        |      20     | 30-674-723-9273 |  -726.50  |  FURNITURE   |        riously special deposits? quickly ironic theodolites cajole carefully upon the regular requests. caref       |
# |   50381   | Customer#000050381 |   QTGDVBuqti1OokFKA0XflVQZnjlG,StzCcOI   |      5      | 15-106-989-8129 |  3197.39  |  HOUSEHOLD   |                           uests wake. furiously regular pinto beans about the carefully t                           |
# |   51381   | Customer#000051381 |           wDdxykN730AAKMO55U7            |      17     | 27-460-421-4775 |  2400.34  |  HOUSEHOLD   |                                          al accounts. furiously final depo                                          |
# |   52381   | Customer#000052381 |             1vinJJugSA1jR8i              |      12     | 22-654-890-5224 |  9298.12  |  AUTOMOBILE  |               furiously regular instructions sleep. ironic theodolites are around the carefully unusua              |
# |   53381   | Customer#000053381 |         p9vaV WsUnYrusLSm2Y52l3          |      18     | 28-218-751-6276 |  1480.11  |  AUTOMOBILE  |     ut the requests wake busily about the furiously even notornis! blithely final ideas against the ruthlessly      |
# |   54381   | Customer#000054381 |        FHyVOqS0JifOmAMbhH69oNhjX         |      11     | 21-817-913-4522 |  9029.33  |  MACHINERY   |                    wake furiously pending orbits. ironic, express foxes nag furiously across the                    |
# |   55381   | Customer#000055381 |           g7Cb4D6zc5l0zmyAkJ2f           |      5      | 15-141-227-1472 |  4349.60  |  MACHINERY   |        ronic packages after the quickly final deposits boost about the slyly even ideas. ironic, final reque        |
# |   56381   | Customer#000056381 | CedPLV7UYt8he D6vPu0X jEtH8ckaZKYZWRY1a  |      21     | 31-136-900-3972 |  3503.27  |  HOUSEHOLD   |                      bout the slyly bold ideas affix around the carefully pending deposits. sly                     |
# |   57381   | Customer#000057381 |       o5YQXsugXXpbIaPgYbuC295mD,Z7       |      13     | 23-458-962-8591 |  4146.29  |  MACHINERY   |        even accounts after the foxes mold furiously unusual theodolites. furiously ironic theodolites alongsi       |
# |   58381   | Customer#000058381 |      YyDaun2RtVYtCpOWFJbcg8cdsCrbHb      |      7      | 17-505-242-2803 |  9767.12  |  MACHINERY   |                                       iously silent courts across the express                                       |
# |   59381   | Customer#000059381 |     cqQ1ijFLLvK PVYGMs4y6pUwZVRJ,LSt     |      8      | 18-346-410-1093 |  9501.92  |  MACHINERY   |                           . blithely regular deposits boost according to the slyly unusua                           |
# |   60381   | Customer#000060381 |       8gysWQuVB2XTS7U4ddB2Lqxl,vTW       |      6      | 16-513-152-6308 |  8373.56  |   BUILDING   |                                            the ruthless, even theodolites                                           |
# |   61381   | Customer#000061381 |    QoDfNoIhSBm9 bZiOl1fNqe4EJksBkiB5o    |      12     | 22-691-400-6898 |   285.49  |  HOUSEHOLD   |      ically ironic grouches sleep. regular, regular requests use quickly. furiously regular foxes above the ste     |
# |   62381   | Customer#000062381 |     UhyfOST9OPQvPEARClp9vHkYsjXJ5H2X     |      6      | 16-819-543-1124 |  1931.78  |  HOUSEHOLD   |                     zzle slyly about the slyly bold somas. special, pending requests wake along                     |
# |   63381   | Customer#000063381 |   rvqT6 UMP8mN5ssLEDOkXBHT3yuAauBLQSI    |      22     | 32-521-442-7383 |  8830.86  |   BUILDING   |                               , unusual platelets haggle slyly across the packages. s                               |
# |   64381   | Customer#000064381 |     dTOkY2vL3 wjDMmeCpf3vncf1rgGTXn      |      20     | 30-935-537-5633 |  4516.20  |  MACHINERY   |              out the furiously ironic asymptotes. quickly bold pinto beans sleep furiously furiously re             |
# |   65381   | Customer#000065381 |    BqGLk3vnpWH6sB29iwuXzQYKJytXnRAZN6    |      5      | 15-911-863-1187 |  -953.00  |   BUILDING   |                      . special pinto beans above the final, silent accounts x-ray furiously reg                     |
# |   66381   | Customer#000066381 |       3zl2Ek0FD EiWJLhPvkOE5oKboI        |      19     | 29-648-839-1688 |  4795.42  |  AUTOMOBILE  |                             ly silent deposits hang blithely silent theodolites. unusua                             |
# |   67381   | Customer#000067381 |        9RV8ruLyl38tBqesYFDGUwKE5l        |      4      | 14-272-521-4143 |  4385.70  |   BUILDING   |            quests are. furiously regular packages cajole quickly. slyly regular platelets cajole quickly            |
# |   68381   | Customer#000068381 |         zDLF6kgF97R2ySUWHsdBEbs          |      12     | 22-901-337-9721 |  5927.75  |  MACHINERY   |                          ely bold packages around the special, silent packages cajole alon                          |
# |   69381   | Customer#000069381 |             LBS7n,UzrjzViNFq             |      3      | 13-689-199-7288 |  2575.19  |  FURNITURE   |             s sleep blithely slyly pending deposits. carefully ironic deposits are even platelets. fluf             |
# |   70381   | Customer#000070381 |       h,AnBorcUYBVFJRK458qybxH,Ijv       |      24     | 34-492-169-6321 |  2952.01  |  FURNITURE   |                                         deposits. quickly final accounts hag                                        |
# |   71381   | Customer#000071381 | fPDSh6SK,E7yLMzZDg0wsOSh v8BlhLG0hZjdAaA |      15     | 25-824-608-1106 |  7267.14  |  HOUSEHOLD   |                 requests nag. fluffily ironic packages haggle quickly after the slyly thin requests.                |
# |   72381   | Customer#000072381 |    sXr1omethxFSyhKTq9sDpZOISy97Hv24r9    |      4      | 14-458-723-5815 |  8426.93  |  HOUSEHOLD   |           the doggedly ironic theodolites: blithely even requests shall have to are. hockey players against         |
# |   73381   | Customer#000073381 |             UJ,CJpqPh9hJZqB              |      4      | 14-595-872-8606 |  8636.95  |  MACHINERY   |    iously regular platelets above the blithely ironic requests affix above the silent ideas. blithely pending acc   |
# |   74381   | Customer#000074381 |             IQILoxNPlxP,0qFH             |      8      | 18-683-719-1569 |  -905.34  |  AUTOMOBILE  |   e furiously. quickly express ideas according to the express, special packages wake express dolphins. slyly expr   |
# |   75381   | Customer#000075381 |        DoTDWJFcKH7QECuo3Yp,0p5LTK        |      18     | 28-126-983-1820 |  8928.07  |  FURNITURE   |             blithely final dolphins. pending deposits affix blithely. requests use carefully quickly unus           |
# |   76381   | Customer#000076381 |     8rZZY2h7W hOcMvQUIoMWQLZhQYwcUX      |      0      | 10-862-567-8738 |   55.06   |   BUILDING   |                          ic foxes. blithely unusual asymptotes sleep furiously. furious exc                         |
# |   77381   | Customer#000077381 |               mpBCZTwbkhEQ               |      10     | 20-426-327-2504 |  1506.36  |  HOUSEHOLD   |                                          t the quietly ironic theodolites.                                          |
# |   78381   | Customer#000078381 |         12grBsz2fZKdFCvPQ,ZCJXd          |      24     | 34-694-276-3370 |  2063.10  |  AUTOMOBILE  |        gular instructions. furiously furious accounts are: regular accounts above the final theodolites cajo        |
# |   79381   | Customer#000079381 |            PnxXO 6Tvqje46ETO7            |      18     | 28-376-194-2683 |  5545.67  |  FURNITURE   |    ly. unusual, even sauternes use furiously furiously special pinto beans. carefully regular pinto beans boost     |
# |   80381   | Customer#000080381 |        bNUumQkCodL5f,VhULjPGagdN         |      15     | 25-478-552-4526 |  7046.78  |  FURNITURE   |                             ully. blithely regular requests use at the carefully expres                             |
# |   81381   | Customer#000081381 |      eia6bBPTRZ7DY30H9NHgoCgBwwill       |      4      | 14-930-448-9415 |  9604.64  |   BUILDING   |                                           bove the requests. unusual, expr                                          |
# |   82381   | Customer#000082381 |           2arN ,xFUQhp6gVbVo,            |      19     | 29-231-169-9132 |   643.55  |  MACHINERY   |                   e furiously beneath the ironic, ironic dependencies. slyly regular realms haggl                   |
# |   83381   | Customer#000083381 | eriGxCZFOJ6nzr3,N7zTIQxkfavw2oqHmxVVnEe  |      17     | 27-453-978-9666 |  8323.38  |   BUILDING   |                   usly pending theodolites snooze quickly quickly final braids. blithely silent pa                  |
# |   84381   | Customer#000084381 |             0ugSA,yU5iwOibbK             |      22     | 32-360-298-6957 |  7800.41  |  FURNITURE   |            foxes sleep above the fluffily regular foxes. enticingly regular requests integrate along the a          |
# |   85381   | Customer#000085381 |      idQAHtdPS2 0UKffe3 EItiaV3fVR       |      1      | 11-529-967-9650 |   166.29  |  AUTOMOBILE  |                              lithely even requests. ironic, regular asymptotes are bol                              |
# |   86381   | Customer#000086381 |      iqRLn1xNwttd,MdgqDe2k 5mg1A5g       |      15     | 25-622-216-9978 |  7620.42  |  MACHINERY   |             deas breach according to the blithely quick ideas. carefully final requests integrate furiou            |
# |   87381   | Customer#000087381 |    T8wjW6CZsZNoeZGGcfPxTTb3t1U7CKBqh9    |      7      | 17-346-374-3962 |  6056.27  |  HOUSEHOLD   |                               theodolites affix along the slyly even accounts. final, r                             |
# |   88381   | Customer#000088381 |       v,7ARSlNlfi1dnyMCesWOJJ3N5Y6       |      21     | 31-801-316-2617 |   90.80   |  MACHINERY   |               dependencies wake silently special, regular instructions. unusual packages are blithely               |
# |   89381   | Customer#000089381 |        lnKxeUHptZbLv8rGjBak FThG2        |      10     | 20-398-827-9297 |  7285.89  |  HOUSEHOLD   |          lly unusual excuses wake against the slyly bold requests. busy packages detect blithely bold requ          |
# |   90381   | Customer#000090381 |             knsp8JpLChbzNnvn             |      15     | 25-106-835-2559 |  3992.95  |  MACHINERY   |                                         egular ideas shall have to use slyly                                        |
# |   91381   | Customer#000091381 |                JgOW2mEIiB                |      20     | 30-943-407-7598 |  4083.90  |   BUILDING   |        ithely pending courts affix alongside of the boldly ironic warhorses. carefully unusual accounts integ       |
# |   92381   | Customer#000092381 |      jvudAe6L1RoQNY5SYuLB268k6b4Dpf      |      2      | 12-899-618-4185 |  9281.97  |  FURNITURE   |                          ronic requests along the busy packages poach slyly according to t                          |
# |   93381   | Customer#000093381 |               4RtxzCwz EmV               |      8      | 18-161-531-1584 |  6387.95  |  HOUSEHOLD   |                                   ar, unusual deposits will have to use slyly bol                                   |
# |   94381   | Customer#000094381 |   vqjVeuxg0M7Q8OVdYRjb8T25cFlxR0laZHIS   |      23     | 33-510-563-4460 |  3585.03  |  FURNITURE   |              ly. quickly regular requests use blithely. regular, final notornis use alongside of the p              |
# |   95381   | Customer#000095381 |       Lv8a9mccY3xIYcVxHYxyYkRg5ZE        |      17     | 27-380-888-3474 |  2484.20  |  FURNITURE   |                        final packages sleep doggedly. quickly special packages sleep carefull                       |
# |   96381   | Customer#000096381 | 21LarYGv7 hFgiHdMclKlMgcDgkb8HigPjnNmw,k |      4      | 14-517-873-2712 |   441.59  |  HOUSEHOLD   |                               sily about the instructions: even, final accounts use sl                              |
# |   97381   | Customer#000097381 |              0PfalqnxZQArb               |      6      | 16-335-708-8475 |   -48.37  |  MACHINERY   |                         thout the carefully special accounts are slyly carefully regular pac                        |
# |   98381   | Customer#000098381 | ,bDJRGY WeQ50D,QzXKxyTA8RNnykaEwjenDuxA  |      15     | 25-580-206-7021 |  5856.28  |  AUTOMOBILE  |  le. regular, final ideas are furiously carefully bold instructions. platelets boost slyly slyly even depths. thin  |
# |   99381   | Customer#000099381 |   wAHOZFVK1VEymex91 10QAEpqMVfU5XAh3Y    |      7      | 17-932-783-4510 |  3831.74  |  FURNITURE   |              l packages. blithely special accounts are blithely. blithely pending foxes are alongside               |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+---------------------------------------------------------------------------------------------------------------------+
# Truncated to displaylimit of 100.

# %%
# %%sql
# -- all customer rows where the c_name starts with a 381
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_name LIKE '381%';
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------+-----------+-------------+---------+-----------+--------------+-----------+
# | c_custkey | c_name | c_address | c_nationkey | c_phone | c_acctbal | c_mktsegment | c_comment |
# +-----------+--------+-----------+-------------+---------+-----------+--------------+-----------+
# +-----------+--------+-----------+-------------+---------+-----------+--------------+-----------+

# %%
# %%sql
# -- all customer rows where the c_name has a combination of any character and 9 and 1
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_name LIKE '%_91%';
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+-----------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                      c_comment                                                       |
# +-----------+--------------------+-----------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# |     91    | Customer#000000091 |  9Sce2m BjvDdjQkqMx8UnrUsJkk1IBAvZPTsA  |      8      | 18-239-400-3677 |  4643.14  |  AUTOMOBILE  |               yly ironic foxes lose slyly pending asymptotes. slyly final theodolites nag blithely ar                |
# |    191    | Customer#000000191 |            cZMo3 b4GwZtUmdbw            |      16     | 26-811-707-6869 |  2945.16  |   BUILDING   |                                         daringly quickly ironic foxes. care                                          |
# |    291    | Customer#000000291 |             2FfdPluDa2fxPaRh            |      8      | 18-657-656-2318 |  4261.68  |  HOUSEHOLD   |  ld deposits. regularly ironic pinto beans cajole permanently furiously express packages. regular, unusual sheaves   |
# |    391    | Customer#000000391 |           BZ,850WgpZ0YSFs79Sb           |      11     | 21-604-451-4462 |  4801.30  |  HOUSEHOLD   |               tions wake about the blithely final instructions. excuses sleep regular requests. slyly                |
# |    491    | Customer#000000491 |        AXsbcyMDujG,CAiEu4FmufbZ1k       |      0      | 10-856-259-7548 |   785.37  |  AUTOMOBILE  |                                ly final, even hockey players. carefully final ideas w                                |
# |    591    | Customer#000000591 |            wkmTqEmyI3UOEoG3q            |      20     | 30-584-309-7885 |  6344.66  |  MACHINERY   |       xpress deposits. slyly ironic ideas haggle: daringly even requests after the quickly final ideas boost q       |
# |    691    | Customer#000000691 |          0aGn3Vcf6ZKi82ogENfnso         |      16     | 26-741-688-4189 |  9566.15  |  MACHINERY   |             ven packages cajole fluffily fluffily unusual frays. ironic excuses sleep furiously. regular             |
# |    791    | Customer#000000791 |           Y14aVvMuDDgnmEuCEPK           |      13     | 23-575-775-4059 |  3694.81  |  HOUSEHOLD   |                                beans use carefully furiously regular deposits. slyly                                 |
# |    891    | Customer#000000891 |            r4,EU38BM0qdbjwqH            |      11     | 21-439-958-7518 |  6032.18  |  FURNITURE   |                                        ong the quickly quick patterns. slyly                                         |
# |    910    | Customer#000000910 |              bKS7h8o7ZEiRj              |      9      | 19-899-463-4292 |  5794.69  |   BUILDING   |                 silent deposits are. blithely final foxes cajole slyly according to the furiously re                 |
# |    911    | Customer#000000911 |        68,LIR0Fhraw6LUTrFW6Ew05u        |      13     | 23-121-746-7339 |  6364.60  |   BUILDING   |     uches. blithely silent requests haggle quick, bold accounts. carefully bold pinto beans according to the no      |
# |    912    | Customer#000000912 |             OaqZYembag,qVEwo            |      14     | 24-348-437-3105 |  3861.36  |  FURNITURE   |                                       s sleep slyly along the regular, even i                                        |
# |    913    | Customer#000000913 |             RCJd97HzePqdmZqv            |      14     | 24-500-946-3315 |  6935.16  |  FURNITURE   |                     symptotes. platelets are carefully carefully special foxes. carefully unusua                     |
# |    914    | Customer#000000914 |          sfm DilMcxoMeKw6sbgj9          |      5      | 15-915-758-7313 |  1230.79  |  MACHINERY   |                              ons. unusual requests cajole blithely boldly regular packa                              |
# |    915    | Customer#000000915 |          FykMsCZp9sPLb5F1Z0kS5F         |      0      | 10-452-398-2445 |  3776.53  |  AUTOMOBILE  |                           he even, bold instructions. quickly final foxes wake thinly care                           |
# |    916    | Customer#000000916 |           S1CTDHEshFRWaWbnVEPv          |      23     | 33-511-587-8754 |   130.59  |  MACHINERY   | ajole packages. carefully final excuses detect carefully among the furiously final instructions. regular courts wake |
# |    917    | Customer#000000917 |    h1r780DE8lF6aGidEsF3Kva80dOlXvtsV    |      1      | 11-100-917-5264 |  3679.65  |  HOUSEHOLD   |              iously slyly express ideas. quickly final ideas above the carefully special requests grow               |
# |    918    | Customer#000000918 |              58ByGoNkaauhU              |      19     | 29-992-318-6425 |  -155.06  |  MACHINERY   |    y regular platelets. regular, unusual packages sleep evenly. slyly bold accounts affix carefully. bold, final     |
# |    919    | Customer#000000919 |               PjkyzB5w39Jg              |      9      | 19-537-180-2200 |  9774.97  |  MACHINERY   |                      furiously regular gifts. stealthily regular instructions use regular, idle                      |
# |    991    | Customer#000000991 |                OgZkswZKF7               |      21     | 31-977-971-6175 |  6533.53  |  AUTOMOBILE  |          y final packages. regular, even pinto beans wake. bold packages run furiously. furious, regular d           |
# |    1091   | Customer#000001091 |         XtMTviXK6RZ91oBw7ynIT4z0        |      17     | 27-336-955-4882 |  -710.53  |   BUILDING   |                         onic accounts are quickly. ironic instructions wake blithely against                         |
# |    1191   | Customer#000001191 |    hRhTNKi3npZGKxPzi5N9pU9b,Rl0ka4ID    |      19     | 29-587-244-2901 |  9088.54  |  AUTOMOBILE  |                                    ic accounts detect requests. final, special de                                    |
# |    1291   | Customer#000001291 |     OKXJGOjIiRtAGTFYYWYaZScffmt0Zw20    |      7      | 17-693-294-2656 |  8227.37  |   BUILDING   |                        s, ironic packages are fluffily around the furiously careful packages                         |
# |    1391   | Customer#000001391 |   UeAdVulIH4V2xQTg56UIUaeHHJthYg81mQa   |      23     | 33-558-545-3053 |  5510.28  |  FURNITURE   |  regular, regular requests. ideas are regular dependencies. foxes among the closely close accounts affix around the  |
# |    1491   | Customer#000001491 |              lH1ibXlwVFBny              |      4      | 14-931-281-5631 |  3739.82  |  HOUSEHOLD   |           y bold hockey players. quickly bold accounts are slyly final, pending dependencies. carefully i            |
# |    1591   | Customer#000001591 |              2fhd7jD4EIxRQZ             |      9      | 19-142-875-7741 |  7470.70  |  FURNITURE   |                               he quickly unusual requests. pending, ironic accounts c                                |
# |    1691   | Customer#000001691 |       qwQH1lfhnAtwhL1hzx5HOvQIupc       |      12     | 22-649-185-6921 |  3367.22  |  AUTOMOBILE  |        ously special packages. fluffily ironic pearls about the bold, special deposits boost closely ironic          |
# |    1791   | Customer#000001791 |  EmxoaiZ0vIi6ATG0WlmnUHUmH2b,aNt Ijz741 |      8      | 18-937-127-3890 |  3917.82  |  HOUSEHOLD   |         packages sleep according to the quickly ironic platelets. fluffily unusual platelets sleep quickly.          |
# |    1891   | Customer#000001891 |           vNJjDAYc l6K18m3ZR,           |      9      | 19-323-409-2180 |  3069.79  |  HOUSEHOLD   |  lar accounts. fluffily final asymptotes sleep blithely final packages. regular theodolites cajole carefully. regu   |
# |    1910   | Customer#000001910 |             gaRu,,M,wYBlxd              |      5      | 15-112-377-2843 |   475.44  |  FURNITURE   |                                           sual packages would are furious                                            |
# |    1911   | Customer#000001911 |               mRGcuFcffluo              |      1      | 11-369-744-8780 |  2601.29  |  HOUSEHOLD   |                     to the carefully final deposits. slyly unusual theodolites detect. regular                       |
# |    1912   | Customer#000001912 | ,qjthdVjnBDVqIOt8rSscRbRuUb6xC7Vvv 8fmP |      20     | 30-784-527-9935 |  3886.95  |  FURNITURE   |        re fluffily special requests. theodolites among the boldly even packages dazzle against the ironic ex         |
# |    1913   | Customer#000001913 |            Y2QT3tHsN0iQtd0Id            |      8      | 18-831-659-1744 |  8031.55  |   BUILDING   |         g to the fluffily final accounts ought to lose unusual, ironic accounts. slyly final deposits will x         |
# |    1914   | Customer#000001914 |        iAoQfLYDacw NbZoijdaSP04G        |      6      | 16-458-421-7729 |  3308.34  |  FURNITURE   |                       ackages nag. blithely regular multipliers are. deposits haggle closely                         |
# |    1915   | Customer#000001915 |      meyaPruBxVxX0,d6umhv7YWz5Z7Kl      |      16     | 26-683-446-1665 |  7268.98  |  AUTOMOBILE  |       efully according to the ruthless, ironic accounts. furiously ironic requests cajole. carefully enticing        |
# |    1916   | Customer#000001916 |             IlkoNN3h5gtwT2ng            |      5      | 15-662-459-4512 |  1768.76  |  HOUSEHOLD   |                         final requests run carefully after the instructions. regular, final                          |
# |    1917   | Customer#000001917 |        L14UMCaEg0j8xFiSrayrj4tyD3       |      7      | 17-940-989-5599 |  3470.08  |  AUTOMOBILE  |   thrash carefully. slyly bold packages sleep against the blithely special instructions. even requests cajole abo    |
# |    1918   | Customer#000001918 |   p9pMyTeP2pw7KyNccs30JB6w7Jc B,x6aHDA  |      9      | 19-987-388-4413 |  8539.61  |  MACHINERY   |                                       refully. blithely final deposits nag car                                       |
# |    1919   | Customer#000001919 |               GDL9O9ta38j               |      18     | 28-664-832-4585 |  6262.18  |  HOUSEHOLD   |                                            dencies cajole around the idea                                            |
# |    1991   | Customer#000001991 |   amsK9oO0Y9mWQtQ6XPXK2JiNezIRhUQSPR,C  |      9      | 19-351-767-3188 |  3517.27  |  FURNITURE   |                    out the furiously dogged escapades. furiously final packages haggle pending e                     |
# |    2091   | Customer#000002091 |            cpAjOTaY0sBMO,ZpO            |      16     | 26-354-387-4231 |  2601.61  |  FURNITURE   |             arefully express accounts. blithely unusual accounts are furiously through the slyly regular             |
# |    2191   | Customer#000002191 |           sk1nfTCwrBZM8k2xlVd           |      7      | 17-107-715-5454 |  2005.99  |  MACHINERY   |                                          bravely regular ideas affix blithel                                         |
# |    2291   | Customer#000002291 |        GqxVD9B tw58tQQv7RODWPF87        |      5      | 15-553-777-4519 |   -13.83  |  AUTOMOBILE  |                     ing to the blithely ironic requests. ruthlessly unusual ideas cajole across                      |
# |    2391   | Customer#000002391 |               rFNT5y y05,               |      24     | 34-538-909-7828 |  -993.93  |   BUILDING   |                                        grate silent accounts. silent deposit                                         |
# |    2491   | Customer#000002491 |         4b,wCPrQI7x4rGlAy,hZkyj5        |      7      | 17-111-683-1091 |  9386.50  |  AUTOMOBILE  |           ts use blithely according to the furiously ironic foxes. carefully even packages alongside of th           |
# |    2591   | Customer#000002591 |             8RLmynQmQ75Wm,c0            |      18     | 28-695-347-3960 |  3319.74  |  FURNITURE   |                           ar accounts detect quickly blithely unusual accounts. blithely                             |
# |    2691   | Customer#000002691 |    A, tJbLStpXccsOpdt8Li6GJX t0T4Xyj    |      21     | 31-383-871-8222 |  1070.53  |  FURNITURE   |                                     platelets. carefully silent platelets are fu                                     |
# |    2791   | Customer#000002791 |     3aQZWTkzULLA2HpXk8sXSnRe,fJQDkNi    |      6      | 16-732-903-5535 |  1382.12  |  AUTOMOBILE  |                                        wake busily above the regular, express                                        |
# |    2891   | Customer#000002891 |               XJ8SXrbwmOO               |      7      | 17-282-306-5219 |  4894.47  |  FURNITURE   |                                   ss foxes. deposits integrate. final instruction                                    |
# |    2910   | Customer#000002910 |    2ooeLaogzg3cTxqgu FRUG5gAtlc5 00p    |      1      | 11-391-736-1612 |  8357.46  |  MACHINERY   |                          e ruthlessly pending accounts. unusual accounts nag. finally even                           |
# |    2911   | Customer#000002911 |               imbkK2N9LrtC              |      19     | 29-365-497-7730 |  2805.23  |  FURNITURE   |                       ter the even packages haggle furiously special requests. carefully unusu                       |
# |    2912   | Customer#000002912 |    A7SbUSVDSpUUWqymJwEfPRHguMfKOO9Sm    |      18     | 28-465-202-9678 |  -552.68  |  HOUSEHOLD   |                                ide of the slyly express packages. furiously regular i                                |
# |    2913   | Customer#000002913 |      ZQyuVx3dgACYpkIiC4Jf9 FYY3UUPIP    |      16     | 26-622-551-8642 |  4101.76  |  HOUSEHOLD   |                                       ly dependencies. quickly regular dolphi                                        |
# |    2914   | Customer#000002914 |             JuBWQZOgRRCi3Uzp            |      19     | 29-736-466-9105 |  -690.62  |  FURNITURE   |        ckages wake up the furiously regular instructions. blithely ironic accounts integrate carefully. pendi        |
# |    2915   | Customer#000002915 |    n15IgA F1JhiKiS6zE,piQ1Tpn2iE8LSE,   |      0      | 10-870-588-4934 |  6748.74  |  FURNITURE   |                 cajole. quickly ironic excuses wake slyly alongside of the blithely pending deposits                 |
# |    2916   | Customer#000002916 |         sC7mIpa9Fbt6acD8XALggWg         |      13     | 23-879-865-6812 |  3052.46  |   BUILDING   |         wake fluffily even foxes. excuses affix. carefully special requests snooze carefully. carefully sly          |
# |    2917   | Customer#000002917 |       bzCDV0m7F0mryJOyoXi2rdeKX4FD      |      17     | 27-939-570-1941 |  7643.30  |  MACHINERY   |       ges are quickly! thinly final theodolites wake blithely. quickly final accounts are furiously quickly b        |
# |    2918   | Customer#000002918 |       x57eK,YVBypNH7rTVA23ne8PtbSO      |      24     | 34-471-745-3416 |   924.86  |  HOUSEHOLD   |             ly after the theodolites. quickly special multipliers nag along the fluffily final instruct              |
# |    2919   | Customer#000002919 | CThKdXAE1WYGIhJq2QPIarekcFW,njEYdm39 TH |      23     | 33-365-556-6915 |  -948.02  |   BUILDING   |                      regular accounts doze finally pending dependencies! furiously unusual foxe                      |
# |    2991   | Customer#000002991 |         Y0wbQA3u4viEZLe ndjwdMCr        |      8      | 18-907-651-5481 |  5549.26  |  FURNITURE   |                            regular dolphins wake carefully deposits. regular, final theodo                           |
# |    3091   | Customer#000003091 |           6aKsMqm7 MyGe634P9Uo          |      2      | 12-848-402-5035 |  2051.91  |  AUTOMOBILE  | s sleep above the blithely ironic platelets. regular dependencies cajole carefully along the unusual instructions.   |
# |    3191   | Customer#000003191 |       WCZjsmPDy2C2admD0R7pVWuTqOR8      |      19     | 29-535-757-7584 |  4314.25  |  MACHINERY   |                                           the final tithes haggle quickly                                            |
# |    3291   | Customer#000003291 |            Pxe1cEVjemTlfg8nU            |      23     | 33-156-325-5084 |  3390.85  |  AUTOMOBILE  |      its. furiously special deposits cajole blithely. quickly even accounts about the unusual, even instructio       |
# |    3391   | Customer#000003391 |     Sz4TynbDQNCL2ax6pJqkyw0dReOy0iN9    |      3      | 13-592-494-2668 |  7742.35  |   BUILDING   |                                           althily regular requests behind                                            |
# |    3491   | Customer#000003491 |   OZruqHXa6KKFaAYZqukGYG,0ee0NkCxLqn2   |      10     | 20-575-983-1678 |  4748.41  |  HOUSEHOLD   |                  . theodolites boost blithely silent foxes. carefully ironic pinto beans nag. speci                  |
# |    3591   | Customer#000003591 |             rq8MAfUlo9HDGtnX            |      2      | 12-340-575-5823 |  3555.85  |   BUILDING   |                                           dencies wake requests. blithely                                            |
# |    3691   | Customer#000003691 |           GQXQ1ZNNWZdXFo88bDP6          |      10     | 20-758-985-1035 |  7967.22  |  MACHINERY   |                                      the deposits. even packages sleep fluffily.                                     |
# |    3791   | Customer#000003791 |    9ApGfY1GaefneFkxeTxsXUJP4L8O9Pzz2k   |      3      | 13-391-929-8365 |  8490.96  |  FURNITURE   |                             y. blithely ironic accounts cajole furiously. pending instru                             |
# |    3891   | Customer#000003891 |    E07vRMZVEz0,U,ls9ik1LqHEQD Dfo7RF    |      1      | 11-927-163-1261 |  7596.67  |  MACHINERY   |                                    equests above the blithely special accounts p                                     |
# |    3910   | Customer#000003910 |          1vCZWFV3OT7wy9E,Ax38e          |      12     | 22-790-171-6270 |  -183.86  |  FURNITURE   |              sts nag slyly. carefully bold packages use thinly. blithely pending ideas haggle furiousl               |
# |    3911   | Customer#000003911 |   taLupgYbVqYG2qBZJAS0 thm6YAF33K,mBS0  |      5      | 15-659-498-3817 |  9712.07  |  MACHINERY   |                        beans. doggedly final accounts sleep daringly. quickly final gifts mai                        |
# |    3912   | Customer#000003912 |   Ex2vR49kgh9wqpjh3KZRtp6RkKX8abQP7Pjg  |      21     | 31-638-158-8616 |   -90.52  |  HOUSEHOLD   |  nic Tiresias. fluffily ironic requests integrate slyly. slyly pending dolphins sleep above the pinto beans! packa   |
# |    3913   | Customer#000003913 |           m4m40RLg,PCxcbhjKg6           |      20     | 30-696-323-1702 |  5572.00  |  AUTOMOBILE  |                          the carefully regular frays. carefully final requests after the car                         |
# |    3914   | Customer#000003914 |             zyIMHcMcJNoJar2             |      2      | 12-575-753-3202 |  3547.25  |  AUTOMOBILE  |             thely special accounts breach about the close accounts. pinto beans are furiously across the             |
# |    3915   | Customer#000003915 |             ZH4YXQa,ta5YRS8             |      23     | 33-825-949-4537 |  7636.45  |  MACHINERY   |                      deposits cajole. requests haggle stealthy requests. furiously regular pac                       |
# |    3916   | Customer#000003916 |     ggw0SBadmA5hsrF6fascba24SG,Zi41Z    |      9      | 19-722-885-6693 |  6798.34  |   BUILDING   |                                 deposits haggle even deposits. even packages haggle f                                |
# |    3917   | Customer#000003917 |       ePYP 5ktlhVj65q9toXLdegV0NU1      |      3      | 13-565-561-9187 |   665.37  |  AUTOMOBILE  |                s nag always behind the special theodolites. slyly special deposits sleep. blithely un                |
# |    3918   | Customer#000003918 |               ZOGlFEQt  0               |      5      | 15-151-728-2791 |  4820.01  |  AUTOMOBILE  |                        as nag carefully around the slyly pending deposits. quickly final req                         |
# |    3919   | Customer#000003919 |              1,HgnDirlzbiW              |      4      | 14-777-583-7788 |  3892.55  |  MACHINERY   |                       ep busily. blithely silent requests use carefully requests. carefully r                        |
# |    3991   | Customer#000003991 |    2bBZwTYrqm6GmBT5Hicw5nR,WswFsX5lJ    |      13     | 23-748-602-7000 |  3428.83  |  HOUSEHOLD   |  dependencies above the pending pinto beans haggle quietly according to the quickly unusual deposits. quickly final  |
# |    4091   | Customer#000004091 |        ZVVbGo8lu7gEc,IpaDhKxf4aZX       |      21     | 31-111-969-4156 |  -741.37  |  MACHINERY   |                                   ent requests poach. unusual ideas cajole furiou                                    |
# |    4191   | Customer#000004191 | xQn,Ct2FcOIRGO0oDH15f4xK0Y3xkZlbpRYHRKd |      23     | 33-821-382-4360 |  -184.42  |  FURNITURE   |                                     courts haggle according to the carefully sp                                      |
# |    4291   | Customer#000004291 |       iuFJPtTUjaPso5MH3VnXGjwfFSnf      |      6      | 16-471-568-8384 |  7857.92  |  AUTOMOBILE  |                        ar, pending packages cajole busy, regular packages. requests use. pla                         |
# |    4391   | Customer#000004391 |        5m,npqN1XFWxtUU27WUw2ARhbm       |      14     | 24-751-261-1267 |  6855.80  |  AUTOMOBILE  |                y across the idly pending pinto beans. unusual dependencies wake slowly. quietly even                 |
# |    4491   | Customer#000004491 |               WOkML0KggEX0              |      0      | 10-641-501-3758 |  3675.40  |  HOUSEHOLD   |                 ve the carefully pending deposits. furiously final instructions sleep carefully. bol                 |
# |    4591   | Customer#000004591 |       ZHdkZWgwqJuo,eNEoRBZrS2kc1L       |      10     | 20-635-983-8796 |  6768.44  |   BUILDING   |                                         sts can are slyly final accounts. fu                                         |
# |    4691   | Customer#000004691 |            WNT23cF4hGohBugKq            |      2      | 12-993-647-5655 |  4453.45  |   BUILDING   |     beans across the quietly even accounts are quickly unusual, pending instructions. carefully pending courts       |
# |    4791   | Customer#000004791 |           FrO2C06CghqdpaxTFgy           |      19     | 29-988-338-5560 |  -855.66  |  HOUSEHOLD   |                ial courts across the ideas breach furiously final frets. carefully pending packages a                |
# |    4891   | Customer#000004891 |               oTCl6WR7sopQ              |      5      | 15-581-478-1018 |  8255.77  |  MACHINERY   |                                        nto beans. even pinto beans according                                         |
# |    4910   | Customer#000004910 |           XqXmWE,9l6hTEOtPTUV           |      6      | 16-316-543-3225 |  7899.03  |  AUTOMOBILE  |                   escapades. carefully final accounts are blithely according to the pending theodol                  |
# |    4911   | Customer#000004911 |    2VoL2bHMsM9y8YWNC1cONCUYq6R0CQEf,    |      1      | 11-357-820-7468 |  9020.78  |  AUTOMOBILE  |                   integrate. furiously pending excuses nag slyly. ironically final foxes are aroun                   |
# |    4912   | Customer#000004912 |     wCg wk7R7inVVjau6RjQEtu JQsYWHvZ    |      9      | 19-977-452-4386 |  8278.92  |  FURNITURE   |                       ar theodolites. theodolites boost blithely regular packages. carefully f                       |
# |    4913   | Customer#000004913 |             xugxsWE0Jx8a2JU             |      9      | 19-504-686-2700 |  2889.70  |  HOUSEHOLD   |        ending dependencies can cajole blithely carefully special packages. brave accounts haggle excuses. bol        |
# |    4914   | Customer#000004914 |            UnWTQiD0LTI6mQ7vzV           |      24     | 34-237-924-3488 |   231.45  |  FURNITURE   |                                         onic dependencies-- carefully even                                           |
# |    4915   | Customer#000004915 |               vuWYJz26e9zb              |      8      | 18-714-666-3485 |  4946.29  |  AUTOMOBILE  |                                even foxes. never express accounts hinder. blithely re                                |
# |    4916   | Customer#000004916 |        X8oR6CijYMgBYkp1GaXfkPBm1Y       |      2      | 12-388-840-9405 |  3335.67  |  AUTOMOBILE  |            aggle slyly furiously final excuses. quickly bold instructions maintain against the fluffily              |
# |    4917   | Customer#000004917 |            E2ks59D1je7PmgB3H            |      20     | 30-977-681-7927 |  4573.06  |  FURNITURE   |                              bold platelets breach slyly at the special, pending accoun                              |
# |    4918   | Customer#000004918 |                K66DxWDlrD               |      21     | 31-359-705-9039 |   478.62  |  HOUSEHOLD   |                                        notornis alongside of the furiously f                                         |
# |    4919   | Customer#000004919 |   PSJl4U458C0A8IVsrJCy5tDhJiJKmofJAeYL  |      6      | 16-838-256-1909 |  1045.14  |  AUTOMOBILE  |       beans despite the pending instructions wake slyly blithely bold pinto beans. accounts haggle slyly speci       |
# |    4991   | Customer#000004991 |       Xsd OmVG8Fa1F3f,7mf9m4bWsKDy      |      15     | 25-393-465-1778 |  -640.28  |  MACHINERY   |                                       furiously express deposits. slyly perma                                        |
# +-----------+--------------------+-----------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# We can also filter for more than one value using `IN` and `NOT IN`.

# %%
# %%sql
# -- all customer rows which have c_nationkey = 10 or c_nationkey = 20
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_nationkey IN (10, 20);
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                 | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                      c_comment                                                       |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# |     16    | Customer#000000016 |           P2IQMff18ercaYrO,40            |      10     | 20-781-609-3107 |  4681.03  |  FURNITURE   |                         ests cajole. pinto beans detect slyly. final packages cajole slyly                           |
# |     41    | Customer#000000041 |     jeREsFtCuMqEwdvTFqTkY2NzGRYDG1m      |      10     | 20-917-711-4011 |   270.95  |  HOUSEHOLD   |       uctions wake carefully pending deposits: pinto beans along the carefully final deposits sleep blithely a       |
# |     49    | Customer#000000049 |  PdKqM4TlA OLTjaeRmvH7QWDu80USfslgqutF   |      10     | 20-908-631-4424 |  4573.94  |  FURNITURE   |                           quests haggle! furiously unusual theodolites cajole carefully. t                           |
# |     55    | Customer#000000055 |  ti9p9XgdmFsjsQI6XQrISDUMFAusnmKS SBoCE  |      10     | 20-180-440-8525 |  4572.11  |  MACHINERY   |    dolites. bold instructions wake fluffily regular ideas. regular theodolites are furiously carefully unusual ac    |
# |     56    | Customer#000000056 |              qh212iaGWtoVp               |      10     | 20-895-685-6920 |  6530.86  |  FURNITURE   |             quickly final dependencies. even dependencies are slyly regularly silent theodolites. slow a             |
# |    104    | Customer#000000104 |     SEOogsfT y09vI2z PcSTnI18U6rNTf      |      10     | 20-966-284-8065 |  -588.38  |  FURNITURE   |                                           efully bold deposits. carefully                                            |
# |    105    | Customer#000000105 |         XI8hMXfr8bIKTGhIRS2sYs,p         |      10     | 20-793-553-6417 |  9091.82  |  MACHINERY   |                                 solve pending, final requests. regular, bold platele                                 |
# |    110    | Customer#000000110 |             FtEbLLBJQ24d2yG              |      10     | 20-893-536-2069 |  7462.99  |  AUTOMOBILE  |   unts. fluffily express dolphins cajole furiously. fluffily special pinto beans about the furiously express asym    |
# |    158    | Customer#000000158 |       ZjQ2uJ,hZUZ,QCi,oNltA40 4dt        |      10     | 20-383-680-1329 |  6160.95  |  AUTOMOBILE  |                                        inal asymptotes. ironic accounts detec                                        |
# |    159    | Customer#000000159 |      hCyzNocUmjEtz5xSYYzUCH1Bk1wF7       |      10     | 20-888-668-2668 |  2060.06  |  HOUSEHOLD   |      refully blithely final orbits. pending, final packages after the carefully ironic platelets nag carefully       |
# |    166    | Customer#000000166 |   ,Vj4kzvCbTUmhLNSVjuyf8716NF5SddgDMY    |      10     | 20-320-530-5920 |  2042.21  |  FURNITURE   |      osits. regular, express deposits hang closely blithely regular platelets. unusual theodolites haggle fluf       |
# |    175    | Customer#000000175 |   T2gZ1u7AC2Yve4DnuFWIzbeffURXkBn1PU7    |      10     | 20-427-617-9922 |  1975.35  |  FURNITURE   |                                         unts are slyly final foxes. always p                                         |
# |    192    | Customer#000000192 |       AnEpYPRNZpiartUaRH7uTU2iTUn        |      10     | 20-750-712-2481 |  8239.96  |  MACHINERY   |                                          luffily special packages boost car                                          |
# |    231    | Customer#000000231 |          5lcJkS1RCJaNztx3Dbwp9w          |      10     | 20-825-880-1065 |   283.55  |   BUILDING   |          rly accounts. frays boost; furiously regular deposits wake about the slyly bold patterns. special           |
# |    248    | Customer#000000248 |              FK7ZVASQzfuQmn              |      10     | 20-447-727-8914 |  8908.35  |  FURNITURE   |               out the blithely express instructions. furiously unusual deposits sleep. quickly even re               |
# |    256    | Customer#000000256 |       NhUqKL2JS,iems1ev2gWpioYLG7        |      10     | 20-229-271-4429 |  1299.92  |  HOUSEHOLD   |  ously fluffily regular packages. requests are. requests are slyly. packages sleep. silent, final theodolites wake   |
# |    289    | Customer#000000289 |  e6IFMKK,D5dGgXg,84,0qqjoM97YhAhsx7eDk8  |      10     | 20-456-773-7693 |  -215.75  |  AUTOMOBILE  |                                          ly even requests about the regula                                           |
# |    306    | Customer#000000306 |       rnCcmj VQaPfiCkieUDoxbmbrSZ        |      10     | 20-109-305-9629 |  3268.01  |  AUTOMOBILE  |                                     iously unusual pinto beans nag carefully: bl                                     |
# |    353    | Customer#000000353 |        NLykoFfWPVAqgNw7MRPIi3sqj         |      10     | 20-733-644-2244 |  3199.03  |   BUILDING   |            grate above the slyly final requests. always special foxes haggle thin instructions. slyly sp             |
# |    356    | Customer#000000356 |         S9Ld37hIwg8CDfYQBZMkWi7          |      10     | 20-415-457-4421 |  2934.06  |  FURNITURE   |                                    inal decoys cajole furiously regular accounts                                     |
# |    405    | Customer#000000405 |  Foadj, hyAIHaRbJQxOYQ1 WBaltNzP1yPnSN   |      10     | 20-509-301-7901 |  7519.14  |  MACHINERY   | ely unusual accounts sleep fluffily quickly unusual packages. blithely even courts haggle? slyly unusual deposits sl |
# |    408    | Customer#000000408 |    8pHPXF0XQMRWhybTXXjnX5nGT97sY2Slp     |      10     | 20-177-807-5661 |  6825.37  |   BUILDING   |             ains. special, silent asymptotes against the deposits cajole slyly about the even, special a             |
# |    468    | Customer#000000468 |            jOPIJryc54PDzvLum             |      10     | 20-489-960-5023 |  9834.19  |  FURNITURE   |                  furiously ironic accounts. requests haggle slyly final requests. regular patterns                   |
# |    494    | Customer#000000494 |     lgK7HklFa o14OGNy8AJ2oCBpKEoJGEi     |      10     | 20-330-453-6579 |  6295.47  |  FURNITURE   |                             oxes. express accounts cajole slyly about the special instru                             |
# |    504    | Customer#000000504 |  Zkx9uXBcfmb46TLicQ0ro2IgSjxez3afcVns,   |      10     | 20-916-264-7594 |    0.51   |  FURNITURE   |                                  ly final excuses against the sly requests haggle                                    |
# |    517    | Customer#000000517 |     F8CVMjSlWmVgKFUYD4y6TWwLtbHcpKXt     |      10     | 20-475-741-4234 |  3959.71  |  FURNITURE   |                               nst the carefully even theodolites haggle furiously acco                               |
# |    523    | Customer#000000523 |      jMc8Lz8DhJUBv29 ,wVyKIkJLDuT1q      |      10     | 20-638-320-5977 |  -275.73  |   BUILDING   |                                raids integrate silent realms. fluffily express packag                                |
# |    537    | Customer#000000537 |                wt3wuo0WHO                |      10     | 20-337-488-6765 |  2614.79  |  FURNITURE   |              foxes sleep. slyly bold dependencies haggle carefully along the special pinto beans. fluffi             |
# |    545    | Customer#000000545 |            rz2vUH0Dn6bOecBnvz            |      10     | 20-849-123-8918 |  7505.33  |  AUTOMOBILE  |        l foxes sleep furiously across the bold packages. slyly bold instructions among the even, even deposit        |
# |    669    | Customer#000000669 |     RuNcXJQ5t248uDAEvo,BZnuUeEXFnnfB     |      10     | 20-471-280-4789 |  6019.20  |  MACHINERY   |                                         , final packages doze across the car                                         |
# |    679    | Customer#000000679 |      jhLZlG1fRiSE0 wDLOCguVB96dH6a5      |      10     | 20-146-696-9508 |  1394.44  |  AUTOMOBILE  |                                          oys. furiously silent pinto beans                                           |
# |    694    | Customer#000000694 |  Y7ClYkAtlRFmObZbK4rdfd0U0hzlAUvWxZWf8   |      10     | 20-646-375-1939 |  2222.65  |   BUILDING   |                              . furiously enticing dependencies are furiously quickly i                               |
# |    713    | Customer#000000713 |              DwrL1iKm8lkbrb              |      10     | 20-595-832-3185 |  3829.03  |  MACHINERY   |              ts: carefully ironic asymptotes use furiously express instructions. dependencies across t               |
# |    738    | Customer#000000738 |        JMOPSSs99dNdXgtw18Qb4m4eHt        |      10     | 20-722-370-5220 |  2734.95  |  MACHINERY   |                   fully ironic instructions. platelets wake furiously regular platelets. carefully                   |
# |    740    | Customer#000000740 |    moM kCzLz4rzp a8tANsfu6aDQaMEPkgkK    |      10     | 20-215-156-3727 |  1733.76  |   BUILDING   |                                         ecial requests around the quickly f                                          |
# |    787    | Customer#000000787 |     wvbMYxe11ZEZeEYt,AsnM8WXlcHYdNE      |      10     | 20-210-617-3870 |   212.16  |  AUTOMOBILE  |                . ironic deposits wake against the ideas. ironic deposits wake fluffily ironic deposit                |
# |    805    | Customer#000000805 |    woguVtOjwvC8LLtPRALISNwAOFRf70Pfqk    |      10     | 20-732-989-5653 |   511.69  |   BUILDING   |       quickly unusual accounts haggle carefully after the even accounts. deposits cajole carefully bravely spec      |
# |    825    | Customer#000000825 |        gSbRSD0uARnTSGEyQNv02T9vt         |      10     | 20-492-863-1129 |  1809.01  |  HOUSEHOLD   |                     ffily final waters sleep accounts. pinto beans against the theodolites wake                      |
# |    907    | Customer#000000907 |          7M5fvEDBOO kZBPbEdTBtn          |      10     | 20-501-816-7673 |  5751.31  |  HOUSEHOLD   |        sts. express packages wake blithely above the carefully pending ideas. carefully silent packages hinde        |
# |    925    | Customer#000000925 | IDr9QtJvT,K4yjdXI9p4 LZ6EAl6bDYUdIVVYMu  |      10     | 20-753-609-6699 |  1939.39  |  AUTOMOBILE  |                                    carefully! fluffily silent instructions after                                     |
# |    989    | Customer#000000989 |       CgxIu5PjU32lh2,y1HkI0D9Qj,3F       |      10     | 20-646-819-6827 |  5453.74  |  AUTOMOBILE  |          bold theodolites. express pearls breach quickly ironically express packages. ironic instructions s          |
# |    1002   | Customer#000001002 |       SSPgEu XH159fm2S4pyt74cCN6N        |      10     | 20-973-622-6579 |  3699.76  |  MACHINERY   |  s are quickly along the theodolites. unusual accounts are about the quickly final deposits. blithely even pinto b   |
# |    1015   | Customer#000001015 |          anh4mFOqGWloSc7T4oz3q           |      10     | 20-134-926-5391 |  6392.00  |  HOUSEHOLD   |                en requests sleep furiously according to the slyly express requests. carefully ironic                 |
# |    1028   | Customer#000001028 |   euEcJjd0vWWQCKa,J18wBCs,rTD PNHQI1cN   |      10     | 20-582-119-3249 |  1915.53  |  AUTOMOBILE  |             g the furiously ironic asymptotes. blithely silent theodolites use fluffily. boldly unusual              |
# |    1035   | Customer#000001035 |  Ut7PaVUVkXqI0Uph,mEacv0kOUP1cbHWDO3CC   |      10     | 20-376-345-3729 |  7499.36  |  AUTOMOBILE  |         equests. slyly unusual pinto beans integrate slyly against the blithely special pinto beans. regula          |
# |    1039   | Customer#000001039 |              mU,Y7LgHmF94 1              |      10     | 20-871-886-9220 |  7618.54  |  FURNITURE   |                          y unusual packages detect according to the special, even packages.                          |
# |    1046   | Customer#000001046 |         yEKAsGt64Xr2sYoYR2eJjKL          |      10     | 20-890-161-8958 |  2311.00  |   BUILDING   |                          s engage behind the busy ideas. carefully regular depths wake fin                           |
# |    1073   | Customer#000001073 |           hmtliZK2e1A85PefeiL            |      10     | 20-774-197-6595 |  8217.23  |   BUILDING   |                      es cajole alongside of the ironically even asymptotes. slyly even platelet                      |
# |    1074   | Customer#000001074 |                Ek0M91KHb                 |      10     | 20-176-839-1649 |   122.67  |   BUILDING   |     se. express, special accounts sleep furiously quickly pending asymptotes. furiously even accounts affix quic     |
# |    1076   | Customer#000001076 |      pZKL,mtI6rkSSb,PBwW6dONKQc9B5q      |      10     | 20-405-710-1902 |  3509.35  |  AUTOMOBILE  |  lithely regular requests sleep furiously ironic deposits. carefully express platelets instead of the furiously unu  |
# |    1110   | Customer#000001110 |      q9D7tT910ZDjcKRGtS8zifitIywJw       |      10     | 20-777-225-9349 |  2041.65  |  HOUSEHOLD   |                                       as nag through the platelets. unusual p                                        |
# |    1127   | Customer#000001127 |       EAZvX6JgIMXiX1Aymi1xtZrVo5D        |      10     | 20-830-875-6204 |  8631.35  |  AUTOMOBILE  |                                    ar packages integrate after the regular hocke                                     |
# |    1158   | Customer#000001158 |  QyqFYOaNwd6ROms8v59FD7P,S f2gnDB5YOh0B  |      10     | 20-487-747-8857 |  3081.79  |  MACHINERY   |                     arefully carefully even theodolites. unusual, regular deposits nod quickly.                      |
# |    1176   | Customer#000001176 |     6,uO,z3deEdPx6h0Akq9CU2ivXLCSWpn     |      10     | 20-141-903-5936 |  5827.59  |   BUILDING   |                    ourts. ironic accounts dazzle. regular, express theodolites are along the pack                    |
# |    1181   | Customer#000001181 |        2ll2ICs7K,x8HcJcPOp6LbgRzN        |      10     | 20-330-305-8843 |  9180.50  |  AUTOMOBILE  |   slyly even pinto beans use slyly final foxes. even, silent dependencies mold among the carefully ironic packages.  |
# |    1187   | Customer#000001187 |             5ZkN6h Xwaf5q1i7             |      10     | 20-543-260-5157 |  -932.96  |  AUTOMOBILE  |  ts. carefully even foxes across the blithely busy excuses dazzle alongside of the regular instructions. furiously   |
# |    1189   | Customer#000001189 |             APD1oQh87mYA4fF              |      10     | 20-746-804-1553 |  3798.28  |  HOUSEHOLD   |      silent requests wake across the special braids. even, express deposits cajole furiously regular packages--      |
# |    1201   | Customer#000001201 |  gLo85h4Cst5ckn40ZKR6403KjW26YCWAFZsq d  |      10     | 20-825-400-1187 |  5165.39  |   BUILDING   |   r foxes boost blithely final accounts. furiously silent ideas unwind. blithely even dependencies wake slyly; sly   |
# |    1269   | Customer#000001269 |    IYJvhkoeB hSjaNhTnBM7uV8kTHWNLyd9     |      10     | 20-818-485-8060 |  2659.68  |   BUILDING   |            refully express ideas. regular deposits are near the ironic epitaphs. blithely unusual reques             |
# |    1301   | Customer#000001301 |    D9,GjMfUk4Klr5bo0EeZiuzNRGXD1mHLnD    |      10     | 20-339-347-9046 |  8966.63  |  MACHINERY   |   ly regular patterns. evenly even ideas affix. carefully express orbits haggle blithely alongside of the pending    |
# |    1309   | Customer#000001309 | vQcJGUXPHMH2 5OWs1XUP0kx17uzejICT4jS45M  |      10     | 20-821-905-5952 |  -922.69  |  AUTOMOBILE  |   ecial deposits. special, pending instructions wake carefully across the blithely regular dolphins. slyly final a   |
# |    1315   | Customer#000001315 |                WhRWZ4uuGm                |      10     | 20-941-614-6433 |  1447.84  |  AUTOMOBILE  |                                       lar requests! requests after the package                                       |
# |    1321   | Customer#000001321 |                O4NXeKba2X                |      10     | 20-571-787-3958 |  3589.49  |  FURNITURE   |                                       usly carefully unusual ideas. carefully                                        |
# |    1328   | Customer#000001328 |           MHgFgmtu7aahHfM8ZeN            |      10     | 20-305-428-9878 |  3264.99  |  AUTOMOBILE  |                y among the furiously dogged theodolites. slyly final requests haggle final, ironic d                 |
# |    1335   | Customer#000001335 |     6MaqhG5A1KG,QN7v8B1UcY15ip,G4CHh     |      10     | 20-744-779-7057 |  8341.67  |   BUILDING   |                                  riously bold asymptotes haggle daringly regular d                                   |
# |    1346   | Customer#000001346 |           PxvsY3wHr5h2m3H2sLf            |      10     | 20-502-685-6183 |  4524.45  |  FURNITURE   |                nstructions. ironic, express deposits engage carefully above the requests. carefully e                |
# |    1369   | Customer#000001369 |         A37vct6,QYRGWdHWfVPZRfIH         |      10     | 20-232-617-7418 |   498.77  |  AUTOMOBILE  |                  heodolites need to are; blithely regular excuses use final, unusual requests. iron                  |
# |    1382   | Customer#000001382 |           yI7eKBs7bArbCgawPDw            |      10     | 20-962-576-3853 |  8898.67  |  AUTOMOBILE  |                       ns use. blithely regular accounts are furiously. even ideas sleep furiou                       |
# |    1412   | Customer#000001412 |     LLziU56rITH2tBw0SKkiB6l 6DNRxJQ      |      10     | 20-715-510-2804 |  6368.38  |   BUILDING   |        ing foxes. even requests integrate furiously even braids. regular packages will play silent deposits.         |
# |    1436   | Customer#000001436 |              H5VE,IGKlmzC0               |      10     | 20-918-593-1860 |  9158.91  |  MACHINERY   |             lphins sleep ironic, final accounts. furiously regular courts are slyly slyly regular packag             |
# |    1443   | Customer#000001443 |     Bypb8fYdwEi3dMbq7rqBYeU6Aj17wQm      |      10     | 20-959-383-4792 |  7141.87  |  HOUSEHOLD   |                      nstructions about the ironic instructions eat carefully final accounts! p                       |
# |    1495   | Customer#000001495 |   USvVjU5h8C0cz0HBMCo49WgQt,TtKeX9yij    |      10     | 20-416-910-7075 |  6227.55  |  FURNITURE   |                          final, final accounts integrate slyly furiously ironic pinto beans-                         |
# |    1501   | Customer#000001501 |              zfhEyIVcK3pae               |      10     | 20-489-284-9686 |  9734.53  |   BUILDING   |                                   side of the furiously even platelets wake quickl                                   |
# |    1507   | Customer#000001507 |           hy5dxuyFDOxx5WW3sBCp           |      10     | 20-694-294-7077 |  5801.76  |   BUILDING   | ely against the bold packages-- ironic ideas boost quickly across the fluffily final instructions. requests grow unt |
# |    1513   | Customer#000001513 | pGmKAY2wHRHkGjw6M6mf8Z6bRkpDjvJmilsa4d7q |      10     | 20-670-367-4252 |  8434.13  |  FURNITURE   |                                          blithely ironic theodolites. regul                                          |
# |    1573   | Customer#000001573 |    COoY AiqYPwy83GPptS3WMCapALCkPUK7     |      10     | 20-170-955-7287 |  9831.27  |  AUTOMOBILE  |                                     bout the pending, express ideas sleep around                                     |
# |    1627   | Customer#000001627 |       a5Vt3dcw,yIMAuiD9yivSFg6X7g        |      10     | 20-566-949-4093 |  1673.17  |  AUTOMOBILE  |                              he regular, express packages haggle carefully against the                               |
# |    1710   | Customer#000001710 |   VGvlX885PL1hqJXcqHO,e8jjwOmk4Hv5LYx    |      10     | 20-393-759-9313 |  8409.91  |  HOUSEHOLD   |                            fix. fluffily regular excuses play. special ideas nod ruthless                            |
# |    1735   | Customer#000001735 |          WR0Pbvrpd82Z2hRzJMyRe           |      10     | 20-343-415-9202 |  7495.94  |  HOUSEHOLD   |           ideas. fluffily ironic foxes sleep-- evenly final requests solve among the pending gifts. regula           |
# |    1769   | Customer#000001769 |     F OJMWVyEVhkxhPVFk4ApMggiG1r HX      |      10     | 20-708-644-8998 |  8457.18  |  AUTOMOBILE  |     ckages kindle instead of the pending theodolites. carefully ironic packages are furiously about the regular      |
# |    1796   | Customer#000001796 | kk9k3iqSqvKLpd8undDSIXhewQivb6hHb7Oxgpfz |      10     | 20-905-459-3952 |  7327.39  |   BUILDING   |                                         inder furiously about the furiously                                          |
# |    1824   | Customer#000001824 |  RdTQ6fMYYJOYfDiB5LT7Ehfs8jSxKKx02BFOPo  |      10     | 20-684-209-1084 |  3177.51  |  AUTOMOBILE  |                              from the express, regular dolphins. slyly special accounts                              |
# |    1832   | Customer#000001832 |      6LLhR0CCpNIrRLAUjBB,ewOmMNxjKr      |      10     | 20-337-677-6483 |  9640.29  |   BUILDING   |             s. slyly unusual deposits grow carefully. slyly special instructions sleep against the blit              |
# |    1841   | Customer#000001841 |                vhfeiAcWcp                |      10     | 20-566-527-9390 |  8053.62  |   BUILDING   |                                      ove the regular foxes wake quickly ironic                                       |
# |    1842   | Customer#000001842 |      92eOh0JkFx37YBMVd9VHum apdnbg       |      10     | 20-148-955-7830 |   233.23  |   BUILDING   |                against the final accounts. carefully ironic requests above the fluffily even platele                 |
# |    1845   | Customer#000001845 |               vjKQrjJDpYR0               |      10     | 20-777-704-2095 |  6567.69  |  MACHINERY   |        kages. quickly regular foxes wake thin, final deposits. somas sleep slyly. furiously special requests         |
# |    1850   | Customer#000001850 |  u2,iJ R DWiyRAsDvAkohOk2635A cCLg5qAag  |      10     | 20-451-644-7838 |   722.28  |   BUILDING   |                                         express courts engage bravely careful                                        |
# |    1875   | Customer#000001875 |          pIv8 Fdc,NwXpwL1rwYdg0          |      10     | 20-222-437-7307 |  9319.39  |  MACHINERY   | the blithely ironic pinto beans. regular, final deposits within the slyly bold instructions cajole across the final  |
# |    1887   | Customer#000001887 |             mRGWYuaeT4imvf8              |      10     | 20-704-266-2935 |  3370.69  |  AUTOMOBILE  |                 ideas cajole furiously against the furiously pending requests. slyly regular courts                  |
# |    1899   | Customer#000001899 |              4xaP,FCPQr13td              |      10     | 20-243-672-4974 |  2869.40  |  MACHINERY   |                                  haggle carefully slyly final deposits. ironic pac                                   |
# |    1934   | Customer#000001934 |       amD3wStjopAa7wYJTHUWWN VI92V       |      10     | 20-656-890-6862 |  2038.31  |  HOUSEHOLD   |              ld depths. dependencies cajole quickly regular packages. ironic, ironic dinos nag across                |
# |    1938   | Customer#000001938 |         jAQ18mPnuq1SQ0uvD50Kk5c7         |      10     | 20-789-331-1347 |  -894.49  |  AUTOMOBILE  |                              y express excuses are carefully regularly ironic accounts.                              |
# |    1945   | Customer#000001945 |     LJFDflvrI0g50eqyyzSiJT3mW5QCmuDQ     |      10     | 20-470-267-5365 |  9880.10  |   BUILDING   |      ng requests. deposits play pending, regular accounts. furiously regular deposits cajole furiously blithely      |
# |    1989   | Customer#000001989 |      14eiBtP3GV3 5T1GjYXKAzV7MlJmyl      |      10     | 20-648-105-6440 |  9859.77  |  MACHINERY   |                  f the blithely even courts. regular packages integrate furiously final accounts.                    |
# |    2005   | Customer#000002005 |       as3fKjFqgqLss9des2eGcU1zOnGk       |      10     | 20-360-101-6891 |  -827.73  |  HOUSEHOLD   |          ts. regular, unusual dolphins hinder fluffily about the fluffily pending packages. carefully pend           |
# |    2030   | Customer#000002030 |     mgZNqoTRV,LEgyUBQ73kiSb,,fr 4FL      |      10     | 20-967-685-8599 |  5839.38  |  FURNITURE   |                       s requests should have to grow of the carefully even deposits. express                         |
# |    2036   | Customer#000002036 |  9af08UhLcRf2JqfMgdKMUpK3 1lWlifvcfXJnw  |      10     | 20-202-263-3492 |  3492.09  |   BUILDING   |         l asymptotes. deposits wake blithely regular sentiments. express deposits run across the furiously           |
# |    2047   | Customer#000002047 |      olJ540qKaWHNoC1r7Evev uBnCX1BU      |      10     | 20-649-596-3329 |  2696.60  |   BUILDING   |                   ages sleep sometimes among the doggedly regular dolphins. carefully final packag                   |
# |     6     | Customer#000000006 |    g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E   |      20     | 30-114-968-4951 |  7638.57  |  AUTOMOBILE  |        quickly silent asymptotes are slyly regular excuses. instructions wake furiously? quickly bold courts p       |
# |     81    | Customer#000000081 |            9jUFbrThIIeoUNd8 9            |      20     | 30-165-277-3269 |  2023.71  |   BUILDING   |                  s against the ironic packages haggle carefully above the slyly express pinto beans                  |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# Truncated to displaylimit of 100.

# %%
# %%sql
# -- all customer rows which have do not have c_nationkey as 10 or 20
# SELECT
#   *
# FROM
#   customer
# WHERE
#   c_nationkey NOT IN (10, 20);
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# | c_custkey |       c_name       |                c_address                 | c_nationkey |     c_phone     | c_acctbal | c_mktsegment |                                                      c_comment                                                       |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# |     1     | Customer#000000001 |            j5JsirBM9PsCy0O1m             |      15     | 25-989-741-2988 |   711.56  |   BUILDING   |                            y final requests wake slyly quickly special accounts. blithely                            |
# |     2     | Customer#000000002 |      487LW1dovn6Q4dMVymKwwLE9OKf3QG      |      13     | 23-768-687-3665 |   121.65  |  AUTOMOBILE  |                           y carefully regular foxes. slyly regular requests about the bli                            |
# |     3     | Customer#000000003 |               fkRGN8nY4pkE               |      1      | 11-719-748-3364 |  7498.12  |  AUTOMOBILE  |        fully. carefully silent instructions sleep alongside of the slyly regular asymptotes. quickly regular         |
# |     4     | Customer#000000004 |               4u58h fqkyE                |      4      | 14-128-190-5944 |  2866.83  |  MACHINERY   |                                   sublate. fluffily even instructions are about th                                   |
# |     5     | Customer#000000005 |       hwBtxkoBF qSW4KrIk5U 2B1AU7H       |      3      | 13-750-942-6364 |   794.47  |  HOUSEHOLD   |                                  equests haggle furiously against the pending packa                                  |
# |     7     | Customer#000000007 |      8OkMVLQ1dK6Mbu6WG9 w4pLGQ n7MQ      |      18     | 28-190-982-9759 |  9561.95  |  AUTOMOBILE  |                    ounts. ironic, regular accounts sleep. final requests haggle quickly after the                    |
# |     8     | Customer#000000008 |  j,pZ,Qp,qtFEo0r0c 92qobZtlhSuOqbE4JGV   |      17     | 27-147-574-9335 |  6819.74  |   BUILDING   |  riously final excuses sublate quickly among the fluffily even foxes. quickly final packages haggle furiously furi   |
# |     9     | Customer#000000009 |        vgIql8H6zoyuLMFNdAMLyE7 H9        |      8      | 18-338-906-3675 |  8324.07  |  FURNITURE   |            ss pinto beans believe slyly quiet deposits-- doggedly bold packages boost. quickly ironic de             |
# |     10    | Customer#000000010 |    Vf mQ6Ug9Ucf5OKGYq fsaX AtfsO7,rwY    |      5      | 15-741-346-9870 |  2753.54  |  HOUSEHOLD   |                                           g quickly after the evenly bold                                            |
# |     11    | Customer#000000011 |         cG48rYjF3Aw7xs hKUXXqmI          |      23     | 33-464-151-3439 |  -272.60  |   BUILDING   |         ng to the regular foxes. furiously final deposits across the final platelets cajole quickly above th         |
# |     12    | Customer#000000012 |              Sb4gxKs7W1AZa               |      13     | 23-791-276-1263 |  3396.49  |  HOUSEHOLD   |        ickly regular dependencies boost blithely around the slyly ironic theodolites. furiously special dolp         |
# |     13    | Customer#000000013 |         Ez3ax0D5HnUbeUVSxoX8a8B          |      3      | 13-761-547-5974 |  3857.34  |   BUILDING   |          quickly brave foxes. blithely even packages against the pinto beans boost furiously against the re          |
# |     14    | Customer#000000014 |             h3GFMzeFfYiamqr              |      1      | 11-845-129-3851 |  5266.30  |  FURNITURE   |                                          r, express foxes cajole slyly aga                                           |
# |     15    | Customer#000000015 |  3y4KK4CcfNwNCTP0u0p1Rk6aeghe3Z30mo0VnD  |      23     | 33-687-542-7601 |  2788.52  |  HOUSEHOLD   |           quests after the furiously ironic platelets are among the express dependencies. carefully even             |
# |     17    | Customer#000000017 |  Js JrVHNAyCYMANzPGzvonS8kX8s3 yeLi3u9T  |      2      | 12-970-682-3487 |    6.34   |  AUTOMOBILE  |                                           fluffily final packages. slyly f                                           |
# |     18    | Customer#000000018 |        YyukcsqIxlyuXs702Rd2Rl9D1z        |      6      | 16-155-215-1315 |  5494.43  |   BUILDING   |                          ickly even packages about the unusual dependencies cajole furious                           |
# |     19    | Customer#000000019 |      yO0XPkiuSWk0vN FfcH5 IA3oBYy        |      18     | 28-396-526-5053 |  8914.71  |  HOUSEHOLD   |                   ly final pinto beans boost carefully. furiously unusual requests boost furiously                   |
# |     20    | Customer#000000020 |              i bGScABFHXdM               |      22     | 32-957-234-8742 |  7603.40  |  FURNITURE   |                        uickly regular instructions hang silent dugouts! regular, regular fox                         |
# |     21    | Customer#000000021 |              42E5BARtqjomD               |      8      | 18-902-614-8344 |  1428.25  |  MACHINERY   |                                e blithely carefully quick sheaves. furiously regular                                 |
# |     22    | Customer#000000022 |       biUBW,0ldzWGT91Doo5b77G6N3Bp       |      3      | 13-806-545-9701 |   591.98  |  MACHINERY   |                                  s. theodolites nag blithely final packages. finall                                  |
# |     23    | Customer#000000023 |     dN2r4,XdTpNXcoVfBKLEP2zz,5DU7g8      |      3      | 13-312-472-8245 |  3332.02  |  HOUSEHOLD   |                furiously regular accounts haggle slyly. special sauternes hinder carefully. fluffily                 |
# |     24    | Customer#000000024 |   k3qlKjqtHuzNAvIFyZX2Yc1crXuMfMU6SbAl   |      13     | 23-127-851-8031 |  9255.67  |  MACHINERY   |                                   s. final hockey players snooze carefully furious                                   |
# |     25    | Customer#000000025 |          kBSktmaKkjm28IFkVypLN           |      12     | 22-603-468-3533 |  7133.70  |  FURNITURE   |     theodolites nag furiously along the asymptotes. furiously special ideas detect. carefully regular instructio     |
# |     26    | Customer#000000026 |             TFH OW1MeFU6OIb              |      22     | 32-363-455-4837 |  5182.05  |  AUTOMOBILE  |                        gainst the express theodolites. deposits sleep furiously. regular, spe                        |
# |     27    | Customer#000000027 |            j8SkiuuBp gBe7,yT             |      3      | 13-137-193-2709 |  5679.84  |   BUILDING   |                                   permanently. slyly ironic dependencies integrat                                    |
# |     28    | Customer#000000028 |        J5tK,OQa07KQSuY5b4qRFYVYRF        |      8      | 18-774-241-1462 |  1007.18  |  FURNITURE   |                                   r accounts are quickly. boldly bold foxes haggle                                   |
# |     29    | Customer#000000029 |     hVQNzLtqGpgUXNMY0wlZVstaf52mXXxJ     |      0      | 10-773-203-7342 |  7618.27  |  FURNITURE   |                                 nod furiously after the final accounts. courts nag qu                                |
# |     30    | Customer#000000030 | EhnzmgkqQw7UXhF0PVdg gLfSAihaaHaD2fZah2  |      1      | 11-764-165-5076 |  9321.01  |   BUILDING   |                                  ep quickly slyly express accounts-- carefully eve                                   |
# |     31    | Customer#000000031 |      g6qoPd,wIQrwUM3dqMP unpruI5zy       |      23     | 33-197-837-7094 |  5236.89  |  HOUSEHOLD   |                                        the bold, silent pinto beans. slyly s                                         |
# |     32    | Customer#000000032 |  InYu1tIr6EjN0nozdpf3hHRA,8FBYIbU1OcYh   |      15     | 25-430-914-2194 |  3471.53  |   BUILDING   |                                   lly carefully unusual accounts. final attainment                                   |
# |     33    | Customer#000000033 |      Bl8FeyfxOpFuRuDEVIPYPz46vNKrn       |      17     | 27-375-391-1280 |   -78.56  |  AUTOMOBILE  |                         , unusual accounts. closely ironic dependencies are slyly. blithely                          |
# |     34    | Customer#000000034 |        bUkRv2UNDOtEycuW,RuKn0eYg6        |      15     | 25-344-968-5422 |  8589.70  |  HOUSEHOLD   |                                    s. furiously final asymptotes wake. ironic fo                                     |
# |     35    | Customer#000000035 |              8mH4knWDpsifY               |      17     | 27-566-888-7431 |  1228.24  |  HOUSEHOLD   |                                cies with the carefully regular sauternes engage caref                                |
# |     36    | Customer#000000036 |          Y7wosIxbsBi,0nNiSG4V7           |      21     | 31-704-669-5769 |  4987.27  |   BUILDING   |                  ys among the accounts affix blithely asymptotes. carefully even deposits are fluff                  |
# |     37    | Customer#000000037 |            Um5WbwJ0X8QCOy75y             |      8      | 18-385-235-7162 |  -917.75  |  FURNITURE   |                              above the slyly regular accounts sleep along the carefull                               |
# |     38    | Customer#000000038 |           RVmMVNRVUSaS9fbsYQBT           |      12     | 22-306-880-7212 |  6345.11  |  HOUSEHOLD   |    ke slyly; deposits thrash doggedly. regular platelets use fluffily. thinly regular pinto beans eat carefully a    |
# |     39    | Customer#000000039 |        EDP9K1bwtXYNLGCA2mrlOM1U,         |      2      | 12-387-467-6509 |  6264.31  |  AUTOMOBILE  |                                           eposits play across the furiousl                                           |
# |     40    | Customer#000000040 |              LcDk4rtJ85,CLw              |      3      | 13-652-915-8939 |  1335.30  |   BUILDING   |                           y. brave accounts wake slyly ironic epitaphs; express packages h                           |
# |     42    | Customer#000000042 |                tI8 wutpGM                |      5      | 15-416-330-4175 |  8727.01  |   BUILDING   |     lphins. blithely bold requests about the special patterns detect quickly regular foxes. furiously express in     |
# |     43    | Customer#000000043 |    Dx8PHkGSFJWLg3XtkzCX28iHRrQXbCRlN     |      19     | 29-316-665-2897 |  9904.28  |  MACHINERY   |        ronic pinto beans. packages sleep. furiously ruthless packages print blithely fluffily even platelets.        |
# |     44    | Customer#000000044 |    dI0Nc9bvnxXHCWu10bSVn,NEJ2kwdyqvI     |      16     | 26-190-260-5375 |  7315.94  |  AUTOMOBILE  |                                        fily regular asymptotes. ironic, pend                                         |
# |     45    | Customer#000000045 |         XwXcOClKCcFek0oQDl0WFNo          |      9      | 19-715-298-9917 |  9983.38  |  AUTOMOBILE  |                                        l excuses are busy accounts. blithely                                         |
# |     46    | Customer#000000046 |               NQ7345EZ,fS                |      6      | 16-357-681-2007 |  5744.59  |  AUTOMOBILE  |    equests integrate fluffily after the carefully special accounts. fluffily regular deposits eat slyly ironic,      |
# |     47    | Customer#000000047 |           Q,6KCP8Am4WrKN5QJd7            |      2      | 12-427-271-9466 |   274.58  |   BUILDING   |                        rding to the final deposits. furiously ironic packages cajole slyly a                         |
# |     48    | Customer#000000048 |             076rIcJpxBmwMEdq             |      0      | 10-508-348-5882 |  3792.50  |   BUILDING   |                  carefully. furiously bold accounts sleep slyly above the even accounts. ironic acc                  |
# |     50    | Customer#000000050 |           S8sn2GGsuputhZaN7irC           |      6      | 16-658-112-3221 |  4266.13  |  MACHINERY   |                           ideas cajole. carefully even warthogs affix ironically quickly re                          |
# |     51    | Customer#000000051 |               y90vmRI7wCX                |      12     | 22-344-885-4251 |   855.87  |  FURNITURE   |                      across the express, bold requests. closely final accounts sleep blithely                        |
# |     52    | Customer#000000052 |       UracAlAA8tSHL5V,poTZIOjh8o,        |      11     | 21-186-284-5998 |  5630.28  |  HOUSEHOLD   |                      ts boost. carefully express waters across the blithely regular foxes inte                       |
# |     53    | Customer#000000053 |    kDQujt7Ll72zSexpBht7Q1WToFWvlcdKIP    |      15     | 25-168-852-5363 |  4113.64  |  HOUSEHOLD   |                      ts. carefully regular ideas across the blithely final packages cajole car                       |
# |     54    | Customer#000000054 |          1GWwLsVwmol4lt0KCz7m1           |      4      | 14-776-370-4745 |   868.90  |  AUTOMOBILE  |      are slyly. instructions sublate slyly. fluffily even packages among the slyly regular accounts hang along       |
# |     57    | Customer#000000057 |              ST32P xcb94b46              |      21     | 31-835-306-1650 |  4151.93  |  AUTOMOBILE  |                     thely pending deposits. packages cajole blithely slyly express requests. fl                      |
# |     58    | Customer#000000058 |     LRQBToGZ8wSLO3m5HBe2Cp1i97CJIr8      |      13     | 23-244-493-2508 |  6478.46  |  HOUSEHOLD   |            ronic accounts dazzle quickly along the blithely special packages. blithely final pinto beans             |
# |     59    | Customer#000000059 |          tfcob0wJRYdypIJLzBckGW          |      1      | 11-355-584-3112 |  3458.60  |  MACHINERY   |                       s asymptotes wake. slyly ironic deposits haggle furiously; slyly regula                        |
# |     60    | Customer#000000060 |           mtCNJIveoJ 1E6sUhs,j           |      12     | 22-480-575-5866 |  2741.87  |  MACHINERY   |            ts. accounts cajole carefully. carefully final requests across the even accounts affix slyly              |
# |     61    | Customer#000000061 | SGDNwNWmqhvJKXwNlrpL4 TqAdz7XRDrKyAIQ2m  |      17     | 27-626-559-8599 |  1536.24  |  FURNITURE   |                                    slyly. quickly unusual deposits haggle furiousl                                   |
# |     62    | Customer#000000062 |               yBhgYoDvZX1                |      7      | 17-361-978-7059 |   595.61  |  MACHINERY   |                e carefully final requests. fluffily regular deposits haggle among the ironic warhors                 |
# |     63    | Customer#000000063 |              j398B6441 Rgii              |      21     | 31-952-552-9584 |  9331.13  |  AUTOMOBILE  |                               ar pinto beans nag furiously furiously regular ideas. d                                |
# |     64    | Customer#000000064 |          fPoMk3Y,GQhgXCQGhn0c8           |      3      | 13-558-731-7204 |  -646.64  |   BUILDING   |                              hely unusual deposits sleep furiously express requests. c                               |
# |     65    | Customer#000000065 | ak7rtta,tWG,jR,cTSXflW6RVQ3alna3P4Q,zF03 |      23     | 33-733-623-5267 |  8795.16  |  AUTOMOBILE  |                         ironic courts sleep slyly above the ironic, bold accounts. blithely                          |
# |     66    | Customer#000000066 |            4PzmA4jZm7Qh22yrZq            |      22     | 32-213-373-5094 |   242.77  |  HOUSEHOLD   |                                  nic instructions are furiously unusual, unusual pa                                  |
# |     67    | Customer#000000067 |        ALk,OdKy V5SruigGvBRMBo8S         |      9      | 19-403-114-4356 |  8166.59  |  MACHINERY   |                                           special sentiments. pending depen                                          |
# |     68    | Customer#000000068 |           DSqIPPo9G3xalJSKl0TC           |      12     | 22-918-832-2411 |  6853.37  |  HOUSEHOLD   |                               e slyly express theodolites kindle fluffily ironic, pend                               |
# |     69    | Customer#000000069 | gyuZTEcR4vKyNPMSa15ueKbRS6Tu4RUxw8j,B mv |      9      | 19-225-978-5670 |  1709.28  |  HOUSEHOLD   |  sauternes against the silent foxes are slyly quickly special deposits. slyly final foxes integrate furiously. care  |
# |     70    | Customer#000000070 |    FlCviyJDjHCYkHoJ22QwH4rG6wcHiQ8oa     |      22     | 32-828-107-2832 |  4867.52  |  FURNITURE   |              le through the carefully unusual accounts. excuses use slyly. furiously pending accounts a              |
# |     71    | Customer#000000071 | 8FkQFLN34pFe50URKft43ntisSegsO3SKF0wUyZp |      7      | 17-710-812-5403 |  -611.19  |  HOUSEHOLD   |                        e slyly about the slyly bold theodolites. furiously regular deposits a                        |
# |     72    | Customer#000000072 | CxyHFFzGum1sz0jBMiqR5AxTNKKjVp6ovnvkjOL  |      2      | 12-759-144-9689 |  -362.86  |  FURNITURE   |                           dolites print blithely about the ironic requests. regular, expre                           |
# |     73    | Customer#000000073 |           TiJiuAMxW6LUyyVFCKW            |      0      | 10-473-439-3214 |  4288.50  |   BUILDING   |                                 carefully pending packages to the pearls affix quick                                 |
# |     74    | Customer#000000074 |     jGhjorX17JmTAfT6gO 6sD9fF1GtFLs      |      4      | 14-199-862-7209 |  2764.43  |  MACHINERY   |                          ithely special excuses. regular deposits cajole furiously finally                           |
# |     75    | Customer#000000075 |        oJrUH20Ovu5fgaLagGIkAswUBF        |      18     | 28-247-803-9025 |  6684.10  |  AUTOMOBILE  |            ronic foxes after the brave hockey players haggle after the slyly ironic courts. even, regular            |
# |     76    | Customer#000000076 |       FXzPoxHecjuQcCLk0Mr6HkbyAPW        |      0      | 10-349-718-3044 |  5745.33  |  FURNITURE   | es snooze about the accounts. furiously unusual excuses sleep furiously around the blithely careful decoys. express, |
# |     77    | Customer#000000077 |          XyqmVhNelkoWPtjz3lRYxu          |      17     | 27-269-357-4674 |  1738.87  |   BUILDING   |         slyly. furiously final accounts sleep slyly among the ironic packages. quickly pending deposits inte         |
# |     78    | Customer#000000078 |       kpcyQ11dABLX6YO9f,GPALyGbws3       |      9      | 19-960-700-9191 |  7136.97  |  FURNITURE   |                                          uriously above the slyly final de                                           |
# |     79    | Customer#000000079 |          EVJjYMyG59w4SINzn0pEfY          |      15     | 25-147-850-4166 |  5121.28  |  MACHINERY   | iously even pinto beans hinder final deposits. carefully final accounts along the final theodolites integrate caref  |
# |     80    | Customer#000000080 |               h0wy3CSA2ps                |      0      | 10-267-172-7101 |  7383.53  |  FURNITURE   |                    ld, bold excuses sleep finally furiously pending pinto beans. furiously expres                    |
# |     82    | Customer#000000082 |        tJkXm2PQBWPRRYkIXPg0YdM03E        |      18     | 28-159-442-5305 |  9468.34  |  AUTOMOBILE  |                                old requests. slyly bold courts sleep carefully packag                                |
# |     83    | Customer#000000083 |     kDJ7dqVuBD9lY,hqjW2O UBz5EGoX9oL     |      22     | 32-817-154-4122 |  6463.51  |   BUILDING   |   into beans alongside of the furiously silent theodolites haggle carefully slyly final sauternes. requests cajol    |
# |     84    | Customer#000000084 |   GB3sUmv RRXV DPzeOSbGxMIF9Z4Eq9 rop    |      11     | 21-546-818-3802 |  5174.71  |  FURNITURE   |                ounts. blithely express theodolites nag carefully ironic pinto beans. carefully final                 |
# |     85    | Customer#000000085 |        I9M GnvICGJ29rTlKGzDMstOgH        |      5      | 15-745-585-8219 |  3386.64  |  FURNITURE   |                                       nts. blithely unusual pinto beans along                                        |
# |     86    | Customer#000000086 |        78Umklj3P783bfR9pzuaizxwt         |      0      | 10-677-951-2353 |  3306.32  |  HOUSEHOLD   |                                     ly despite the slyly pending platelets. reg                                      |
# |     87    | Customer#000000087 |            KKkJj684aFsUH1Unw             |      23     | 33-869-884-7053 |  6327.54  |  FURNITURE   |                  boost carefully. blithely furious Tiresias nag furiously ironic foxes. instruction                  |
# |     88    | Customer#000000088 |     wyGHpeRMt mxmd8fEelFiXMTHnVg3OL      |      16     | 26-516-273-2566 |  8031.44  |  AUTOMOBILE  |         ts. unusual foxes use excuses; final courts doubt special packages. furiously regular platelets abo          |
# |     89    | Customer#000000089 |        Oy90ruRha47cUlCimutBTvJc6         |      14     | 24-394-451-5404 |  1530.76  |  FURNITURE   |                    theodolites x-ray carefully even pinto beans. carefully final requests dazzle                     |
# |     90    | Customer#000000090 |             buosjU5uu274vLfU             |      16     | 26-603-491-1238 |  7354.23  |   BUILDING   |                                            lyly bold pinto beans use alon                                            |
# |     91    | Customer#000000091 |  9Sce2m BjvDdjQkqMx8UnrUsJkk1IBAvZPTsA   |      8      | 18-239-400-3677 |  4643.14  |  AUTOMOBILE  |               yly ironic foxes lose slyly pending asymptotes. slyly final theodolites nag blithely ar                |
# |     92    | Customer#000000092 | DPbrb7fGYfkrfAdm0gRJPPdADgqGh5 FVuA9 20  |      2      | 12-446-416-8471 |  1182.91  |  MACHINERY   |                                     sy theodolites. furiously ironic packages a                                      |
# |     93    | Customer#000000093 |                nj3p ZakNJ                |      7      | 17-359-388-5266 |  2182.52  |  MACHINERY   |                                    gular decoys after the slyly ruthless deposit                                     |
# |     94    | Customer#000000094 |    jL5dieRgyG9OhRN7HgXbLVK2ZRlMQ3NvvL    |      9      | 19-953-499-8833 |  5500.11  |  HOUSEHOLD   |    ges wake deposits. unusual, special forges wake. final packages cajole blithely across the special dolphins.      |
# |     95    | Customer#000000095 |     n6,uwF4wcE76DVh1YsSVoatkTbohR3BT     |      15     | 25-923-255-2929 |  5327.38  |  MACHINERY   |         ly regular dinos. ironic requests haggle. slyly final accounts haggle slyly across the carefully exp         |
# |     96    | Customer#000000096 |                x4fc F3J99                |      8      | 18-422-845-1202 |  6323.92  |  AUTOMOBILE  |                  lyly brave platelets are furiously above the fluffily sly theodolites. quickly ev                   |
# |     97    | Customer#000000097 |          dqBtMIPJhk1,ivXIr NZf           |      17     | 27-588-919-5638 |  2164.48  |  AUTOMOBILE  |                      cial instructions. dependencies boost furiously; quickly final requests w                       |
# |     98    | Customer#000000098 |            UtIJM4d8BxnqvPzwn4            |      12     | 22-885-845-6889 |  -551.37  |   BUILDING   |                    ges. quickly regular theodolites wake. blithely unusual packages wake fluffil                     |
# |     99    | Customer#000000099 |              sz cJbyoj68RTfz             |      15     | 25-515-237-9232 |  4088.65  |  HOUSEHOLD   |  ly slow platelets. regular asymptotes toward the quickly even accounts sleep after the fluffily ironic deposits. b  |
# |    101    | Customer#000000101 |             eEfYAdMjnGyCw8Fr2            |      2      | 12-514-298-3699 |  7470.96  |  MACHINERY   |                                  pending deposits sleep slyly carefully regular re                                   |
# |    102    | Customer#000000102 |       7qyLFi,UrLERspLhHiDGb1F4yBQq       |      19     | 29-324-978-8538 |  8462.17  |   BUILDING   |                   the ironic accounts. bravely regular instructions above the furiously express as                   |
# |    103    | Customer#000000103 |     Tgiza4WfhTbezHUo yly4x,D6nN50SR      |      9      | 19-216-107-2107 |  2757.45  |   BUILDING   |     ending accounts along the packages use according to the sly, special ideas. instructions above the carefull      |
# |    106    | Customer#000000106 |               vkocmr6H6dl                |      1      | 11-751-989-4627 |  3288.42  |  MACHINERY   |        ns are furiously final foxes. slyly even accounts thrash fluffily. slyly regular accounts across the u        |
# |    107    | Customer#000000107 |      2vKUW710ATl9ACXtETbZz1i9zKpns       |      15     | 25-336-529-9919 |  2514.15  |  AUTOMOBILE  |          iously unusual pinto beans sleep quickly under the regular packages. regular theodolites around th          |
# |    108    | Customer#000000108 |                lbCMmxBgCZ                |      5      | 15-908-619-7526 |  2259.38  |   BUILDING   |                         nusual accounts unwind carefully final requests. unusual foxes hagg                          |
# |    109    | Customer#000000109 |   dccG2qKoesLea36FGCOCgPVU M N4BZdmYO    |      16     | 26-992-422-8153 |  -716.10  |   BUILDING   |  osits; blithely special braids across the slyly unusual foxes haggle carefully regularly regular deposits. furiou   |
# |    111    | Customer#000000111 |       pp8Pbuc49CAFCHY8pw gSABRykpz       |      22     | 32-582-283-7528 |  6505.26  |  MACHINERY   | lithely ironic requests haggle thinly against the regular platelets. slyly silent deposits use carefully accounts.   |
# +-----------+--------------------+------------------------------------------+-------------+-----------------+-----------+--------------+----------------------------------------------------------------------------------------------------------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# We can get the number of rows in a table using `count(*)` as shown below.

# %%
# %%sql
# SELECT
#   COUNT(*)
# FROM
#   customer;
# Out:
# Running query in 'duckdb:///tpch.db'
# +--------------+
# | count_star() |
# +--------------+
# |    150000    |
# +--------------+

# %%
# %%sql
# SELECT
#   COUNT(*)
# FROM
#   lineitem;
# Out:
# Running query in 'duckdb:///tpch.db'
# +--------------+
# | count_star() |
# +--------------+
# |   6001215    |
# +--------------+

# %% [markdown]
# If we want to get the rows sorted by values in a specific column, we use `ORDER BY`, for example.

# %%
# %%sql
# -- Will show the first ten customer records with the lowest custkey
# -- rows are ordered in ASC order by default
# SELECT
#   *
# FROM
#   orders
# ORDER BY
#   o_custkey
# LIMIT
#   10;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+--------------------------------------------------------------------------------+
# | o_orderkey | o_custkey | o_orderstatus | o_totalprice | o_orderdate | o_orderpriority |     o_clerk     | o_shippriority |                                   o_comment                                    |
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+--------------------------------------------------------------------------------+
# |   454791   |     1     |       F       |   74602.81   |  1992-04-19 |     1-URGENT    | Clerk#000000815 |       0        |                   ccounts sleep carefully along the slyly ev                   |
# |  4273923   |     1     |       O       |   95911.01   |  1997-03-23 |     3-MEDIUM    | Clerk#000000381 |       0        |                         he even deposits-- even, even                          |
# |  5133509   |     1     |       O       |  174645.94   |  1996-07-01 |     1-URGENT    | Clerk#000000463 |       0        |                e across the furiously ironic deposits. furious                 |
# |   579908   |     1     |       O       |   54048.26   |  1996-12-09 |      5-LOW      | Clerk#000000783 |       0        |  t packages hinder bold, even dolphins. slyly ironic packages wake fluffily a  |
# |  3868359   |     1     |       F       |  123076.84   |  1992-08-22 |      5-LOW      | Clerk#000000536 |       0        |        ependencies boost blithely pending pinto beans. regular asymptot        |
# |  4808192   |     1     |       O       |   65478.05   |  1996-06-29 |      2-HIGH     | Clerk#000000473 |       0        |  nag. final, special deposits believe carefully carefully express accounts. qu |
# |   430243   |     2     |       F       |   33082.83   |  1994-12-24 | 4-NOT SPECIFIED | Clerk#000000121 |       0        |                e slyly along the furiously pending attainments                 |
# |  1071617   |     2     |       P       |  221397.35   |  1995-03-10 |      2-HIGH     | Clerk#000000408 |       0        |         e carefully according to the furiously even packages. furious          |
# |  1374019   |     2     |       F       |  167016.61   |  1992-04-05 |     1-URGENT    | Clerk#000000440 |       0        |                              uick, unusual courts                              |
# |  2992930   |     2     |       F       |  103297.68   |  1994-05-21 | 4-NOT SPECIFIED | Clerk#000000913 |       0        |   even instructions affix slyly. furiously permanent decoys are furiously bli  |
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+--------------------------------------------------------------------------------+

# %%
# %%sql
# -- Will show the first ten customer's records with the highest custkey
# SELECT
#   *
# FROM
#   orders
# ORDER BY
#   o_custkey DESC
# LIMIT
#   10;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+-------------------------------------------------------------------+
# | o_orderkey | o_custkey | o_orderstatus | o_totalprice | o_orderdate | o_orderpriority |     o_clerk     | o_shippriority |                             o_comment                             |
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+-------------------------------------------------------------------+
# |  1070880   |   149999  |       O       |  126063.49   |  1995-12-02 |     3-MEDIUM    | Clerk#000000241 |       0        |   alongside of the slyly final accounts. ironic ideas are furious |
# |  2488608   |   149999  |       F       |  139853.06   |  1994-10-07 |      2-HIGH     | Clerk#000000881 |       0        |                  even accounts may serve carefull                 |
# |  2502080   |   149999  |       O       |  328596.74   |  1996-06-29 |     1-URGENT    | Clerk#000000207 |       0        |                       e. bold dolphins prin                       |
# |  3775524   |   149999  |       O       |   11414.72   |  1995-06-09 |      2-HIGH     | Clerk#000000262 |       0        |     ly around the slyly final instructions. furiously special     |
# |  4014148   |   149999  |       F       |  223396.15   |  1993-05-13 |      5-LOW      | Clerk#000000326 |       0        | forges sleep across the ironic requests. furiously express accoun |
# |  4136421   |   149999  |       F       |  169716.79   |  1993-05-02 | 4-NOT SPECIFIED | Clerk#000000691 |       0        |      s. fluffily regular packages are carefully unusual theo      |
# |  5200769   |   149999  |       O       |  163831.43   |  1995-05-09 |     1-URGENT    | Clerk#000000394 |       0        |     efully silent excuses. slyly express excuses after the pac    |
# |  5323939   |   149999  |       F       |  212230.94   |  1994-03-05 |      2-HIGH     | Clerk#000000425 |       0        |           rint along the carefully bold dolphins. blith           |
# |  5354048   |   149999  |       F       |   34669.55   |  1993-09-14 | 4-NOT SPECIFIED | Clerk#000000910 |       0        |         uriously above the careful deposits. theodolites d        |
# |  5373249   |   149999  |       O       |   46217.79   |  1998-07-06 |      2-HIGH     | Clerk#000000744 |       0        |                      luffily carefully expre                      |
# +------------+-----------+---------------+--------------+-------------+-----------------+-----------------+----------------+-------------------------------------------------------------------+

# %% [markdown]
# # [JOINS] Combine data from multiple tables using JOINs (there are different types of JOINs)
#
# We can combine data from multiple tables using joins. When we write a join query, we have a format as shown below.
#
# ```sql
# -- not based on real tables
# SELECT
#     a.*
# FROM
#     table_a a -- LEFT table a
#     JOIN table_b b -- RIGHT table b
#     ON a.id = b.id
# ```
#
# The table specified first (table_a) is the left table, whereas the table established second is the right table. When we have multiple tables joined, we consider the joined dataset from the first two tables as the left table and the third table as the right table (The DB optimizes the joins for performance).
#
# ```sql
# -- not based on real tables
# SELECT
#     a.*
# FROM
#     table_a a -- LEFT table a
#     JOIN table_b b -- RIGHT table b
#     ON a.id = b.id
#     JOIN table_c c -- LEFT table is the joined data from
# -- table_a & table_b, right table is table_c
#     ON a.c_id = c.id
# ```
#
# There are five main types of joins, they are:
#
# ## 1. Inner join (default): Get only rows in both tables

# %%
# %%sql
# SELECT
#   o.o_orderkey,
#   l.l_orderkey
# FROM
#   orders o
#   JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY
# LIMIT
#   100;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+------------+
# | o_orderkey | l_orderkey |
# +------------+------------+
# |     7      |     7      |
# |     32     |     32     |
# |     33     |     33     |
# |     69     |     69     |
# |     71     |     71     |
# |    133     |    133     |
# |    198     |    198     |
# |    259     |    259     |
# |    260     |    260     |
# |    288     |    288     |
# |    353     |    353     |
# |    354     |    354     |
# |    420     |    420     |
# |    482     |    482     |
# |    485     |    485     |
# |    486     |    486     |
# |    512     |    512     |
# |    517     |    517     |
# |    548     |    548     |
# |    576     |    576     |
# |    576     |    576     |
# |    581     |    581     |
# |    614     |    614     |
# |    678     |    678     |
# |    679     |    679     |
# |    737     |    737     |
# |    771     |    771     |
# |    771     |    771     |
# |    772     |    772     |
# |    774     |    774     |
# |    899     |    899     |
# |    962     |    962     |
# |    962     |    962     |
# |    992     |    992     |
# |    992     |    992     |
# |    1027    |    1027    |
# |    1088    |    1088    |
# |    1095    |    1095    |
# |    1095    |    1095    |
# |    1120    |    1120    |
# |    1186    |    1186    |
# |    1252    |    1252    |
# |    1284    |    1284    |
# |    1287    |    1287    |
# |    1314    |    1314    |
# |    1410    |    1410    |
# |    1571    |    1571    |
# |    1573    |    1573    |
# |    1574    |    1574    |
# |    1605    |    1605    |
# |    1639    |    1639    |
# |    1639    |    1639    |
# |    1664    |    1664    |
# |    1667    |    1667    |
# |    1667    |    1667    |
# |    1671    |    1671    |
# |    1735    |    1735    |
# |    1767    |    1767    |
# |    1824    |    1824    |
# |    1856    |    1856    |
# |    1891    |    1891    |
# |    1923    |    1923    |
# |    1954    |    1954    |
# |    1956    |    1956    |
# |    1991    |    1991    |
# |   122375   |   122375   |
# |   122404   |   122404   |
# |   122406   |   122406   |
# |   122432   |   122432   |
# |   122464   |   122464   |
# |   122468   |   122468   |
# |   122535   |   122535   |
# |   122566   |   122566   |
# |   122595   |   122595   |
# |   122658   |   122658   |
# |   122663   |   122663   |
# |   122784   |   122784   |
# |   122791   |   122791   |
# |   122885   |   122885   |
# |   122948   |   122948   |
# |   122977   |   122977   |
# |   122980   |   122980   |
# |   123011   |   123011   |
# |   123040   |   123040   |
# |   123139   |   123139   |
# |   123139   |   123139   |
# |   123168   |   123168   |
# |   123204   |   123204   |
# |   123206   |   123206   |
# |   123207   |   123207   |
# |   123239   |   123239   |
# |   123271   |   123271   |
# |   123271   |   123271   |
# |   123296   |   123296   |
# |   123361   |   123361   |
# |   123363   |   123363   |
# |   123425   |   123425   |
# |   123427   |   123427   |
# |   123429   |   123429   |
# |   123463   |   123463   |
# +------------+------------+
# Truncated to displaylimit of 100.

# %%
# %%sql
# SELECT
#   COUNT(o.o_orderkey) AS order_rows_count,
#   COUNT(l.l_orderkey) AS lineitem_rows_count
# FROM
#   orders o
#   JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------------+---------------------+
# | order_rows_count | lineitem_rows_count |
# +------------------+---------------------+
# |      247650      |        247650       |
# +------------------+---------------------+

# %% [markdown]
# **Note:** JOIN defaults to INNER JOIN.
#
# The output will have rows from orders and lineitem that found at least one matching row from the other table with the specified join condition (same o_orderkey and orderdate within ship date +/- 5 days).
#
# We can also see that 247650 rows from orders and lineitem tables matched.
#
# ## 2. Left outer join (aka left join): Get all rows from the left table and only matching rows from the right table.

# %%
# %%sql
# SELECT
#   o.o_orderkey,
#   l.l_orderkey
# FROM
#   orders o
#   LEFT JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY
# LIMIT
#   100;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+------------+
# | o_orderkey | l_orderkey |
# +------------+------------+
# |   122375   |   122375   |
# |   122404   |   122404   |
# |   122406   |   122406   |
# |   122432   |   122432   |
# |   122464   |   122464   |
# |   122468   |   122468   |
# |   122535   |   122535   |
# |   122566   |   122566   |
# |   122595   |   122595   |
# |   122658   |   122658   |
# |   122663   |   122663   |
# |   122784   |   122784   |
# |   122791   |   122791   |
# |   122885   |   122885   |
# |   122948   |   122948   |
# |   122977   |   122977   |
# |   123011   |   123011   |
# |   123040   |   123040   |
# |   123139   |   123139   |
# |   123139   |   123139   |
# |   123168   |   123168   |
# |   123204   |   123204   |
# |   123206   |   123206   |
# |   123207   |   123207   |
# |   123239   |   123239   |
# |   123271   |   123271   |
# |   123271   |   123271   |
# |   123296   |   123296   |
# |   123361   |   123361   |
# |   123363   |   123363   |
# |   123425   |   123425   |
# |   123427   |   123427   |
# |   123429   |   123429   |
# |   123463   |   123463   |
# |   123490   |   123490   |
# |   123491   |   123491   |
# |   123584   |   123584   |
# |   123623   |   123623   |
# |   123651   |   123651   |
# |   123684   |   123684   |
# |   123685   |   123685   |
# |   123685   |   123685   |
# |   123712   |   123712   |
# |   123714   |   123714   |
# |   123719   |   123719   |
# |   123777   |   123777   |
# |   123809   |   123809   |
# |   123811   |   123811   |
# |   123813   |   123813   |
# |   123815   |   123815   |
# |   123843   |   123843   |
# |   123876   |   123876   |
# |   123877   |   123877   |
# |   123905   |   123905   |
# |   123943   |   123943   |
# |   123969   |   123969   |
# |   124004   |   124004   |
# |   124005   |   124005   |
# |   124067   |   124067   |
# |   124096   |   124096   |
# |   124163   |   124163   |
# |   124199   |   124199   |
# |   124256   |   124256   |
# |   124256   |   124256   |
# |   124258   |   124258   |
# |   124261   |   124261   |
# |   124261   |   124261   |
# |   124293   |   124293   |
# |   124356   |   124356   |
# |     7      |     7      |
# |     32     |     32     |
# |     33     |     33     |
# |     69     |     69     |
# |     71     |     71     |
# |    133     |    133     |
# |    198     |    198     |
# |    259     |    259     |
# |    260     |    260     |
# |    288     |    288     |
# |    353     |    353     |
# |    354     |    354     |
# |    420     |    420     |
# |    482     |    482     |
# |    485     |    485     |
# |    486     |    486     |
# |    512     |    512     |
# |    517     |    517     |
# |    548     |    548     |
# |    576     |    576     |
# |    576     |    576     |
# |    581     |    581     |
# |    614     |    614     |
# |    678     |    678     |
# |    679     |    679     |
# |    737     |    737     |
# |    771     |    771     |
# |    771     |    771     |
# |    772     |    772     |
# |    774     |    774     |
# |    899     |    899     |
# +------------+------------+
# Truncated to displaylimit of 100.

# %%
# %%sql
# SELECT
#   COUNT(o.o_orderkey) AS order_rows_count,
#   COUNT(l.l_orderkey) AS lineitem_rows_count
# FROM
#   orders o
#   LEFT JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------------+---------------------+
# | order_rows_count | lineitem_rows_count |
# +------------------+---------------------+
# |     1519332      |        247650       |
# +------------------+---------------------+

# %% [markdown]
# The output will have all the rows from orders and the rows from lineitem that were able to find at least one matching row from the orders table with the specified join condition (same o_orderkey and orderdate within ship date +/- 5 days).
#
# We can also see that the number of rows from the orders table is 1,519,332 & from the lineitem table is 247,650. The number of rows in orders is 1,500,000, but the join condition produces 1,519,332 since some orders match with multiple lineitems.
#
# ## 3. Right outer join (aka right join): Get matching rows from the left and all rows from the right table.

# %%
# %%sql
# SELECT
#   o.o_orderkey,
#   l.l_orderkey
# FROM
#   orders o
#   RIGHT JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY
# LIMIT
#   100;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+------------+
# | o_orderkey | l_orderkey |
# +------------+------------+
# |     7      |     7      |
# |     32     |     32     |
# |     33     |     33     |
# |     69     |     69     |
# |     71     |     71     |
# |    133     |    133     |
# |    198     |    198     |
# |    259     |    259     |
# |    260     |    260     |
# |    288     |    288     |
# |    353     |    353     |
# |    354     |    354     |
# |    420     |    420     |
# |    482     |    482     |
# |    485     |    485     |
# |    486     |    486     |
# |    512     |    512     |
# |    517     |    517     |
# |    548     |    548     |
# |    576     |    576     |
# |    576     |    576     |
# |    581     |    581     |
# |    614     |    614     |
# |    678     |    678     |
# |    679     |    679     |
# |    737     |    737     |
# |    771     |    771     |
# |    771     |    771     |
# |    772     |    772     |
# |    774     |    774     |
# |    899     |    899     |
# |    962     |    962     |
# |    962     |    962     |
# |    992     |    992     |
# |    992     |    992     |
# |    1027    |    1027    |
# |    1088    |    1088    |
# |    1095    |    1095    |
# |    1095    |    1095    |
# |    1120    |    1120    |
# |    1186    |    1186    |
# |    1252    |    1252    |
# |    1284    |    1284    |
# |    1287    |    1287    |
# |    1314    |    1314    |
# |    1410    |    1410    |
# |    1506    |    1506    |
# |    1506    |    1506    |
# |    1571    |    1571    |
# |    1573    |    1573    |
# |    1574    |    1574    |
# |    1605    |    1605    |
# |    1639    |    1639    |
# |    1639    |    1639    |
# |    1664    |    1664    |
# |    1667    |    1667    |
# |    1667    |    1667    |
# |    1671    |    1671    |
# |    1735    |    1735    |
# |    1767    |    1767    |
# |    1794    |    1794    |
# |    1824    |    1824    |
# |    1825    |    1825    |
# |    1856    |    1856    |
# |    1891    |    1891    |
# |    1923    |    1923    |
# |    1954    |    1954    |
# |    1956    |    1956    |
# |    1991    |    1991    |
# |   122375   |   122375   |
# |   122404   |   122404   |
# |   122406   |   122406   |
# |   122432   |   122432   |
# |   122464   |   122464   |
# |   122468   |   122468   |
# |   122535   |   122535   |
# |   122566   |   122566   |
# |   122595   |   122595   |
# |   122658   |   122658   |
# |   122663   |   122663   |
# |   122784   |   122784   |
# |   122791   |   122791   |
# |   122885   |   122885   |
# |   122948   |   122948   |
# |   122977   |   122977   |
# |   122980   |   122980   |
# |   123011   |   123011   |
# |   123040   |   123040   |
# |   123139   |   123139   |
# |   123139   |   123139   |
# |   123168   |   123168   |
# |   123204   |   123204   |
# |   123206   |   123206   |
# |   123207   |   123207   |
# |   123239   |   123239   |
# |   123271   |   123271   |
# |   123271   |   123271   |
# |   123296   |   123296   |
# |   123361   |   123361   |
# |   123363   |   123363   |
# +------------+------------+
# Truncated to displaylimit of 100.

# %%
# %%sql
# SELECT
#   COUNT(o.o_orderkey) AS order_rows_count,
#   COUNT(l.l_orderkey) AS lineitem_rows_count
# FROM
#   orders o
#   JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------------+---------------------+
# | order_rows_count | lineitem_rows_count |
# +------------------+---------------------+
# |      247650      |        247650       |
# +------------------+---------------------+

# %% [markdown]
# The output will have the rows from orders that found at least one matching row from the lineitem table with the specified join condition (same o_orderkey and orderdate within ship date +/- 5 days) and all the rows from the lineitem table.
#
# We can also see that the number of rows from the orders table is 247,650 & from the lineitem table is 6,001,215 .
#
# ## 4. Full outer join: Get all rows from both the left and right tables.

# %%
# %%sql
# SELECT
#   o.o_orderkey,
#   l.l_orderkey
# FROM
#   orders o
#   FULL OUTER JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY
# LIMIT
#   100;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+------------+
# | o_orderkey | l_orderkey |
# +------------+------------+
# |   122375   |   122375   |
# |   122404   |   122404   |
# |   122406   |   122406   |
# |   122432   |   122432   |
# |   122464   |   122464   |
# |   122468   |   122468   |
# |   122535   |   122535   |
# |   122566   |   122566   |
# |   122595   |   122595   |
# |   122658   |   122658   |
# |   122663   |   122663   |
# |   122691   |   122691   |
# |   122784   |   122784   |
# |   122791   |   122791   |
# |   122885   |   122885   |
# |   122948   |   122948   |
# |   122977   |   122977   |
# |   122980   |   122980   |
# |   123011   |   123011   |
# |   123040   |   123040   |
# |   123139   |   123139   |
# |   123139   |   123139   |
# |   123168   |   123168   |
# |   123204   |   123204   |
# |   123206   |   123206   |
# |   123207   |   123207   |
# |   123239   |   123239   |
# |   123271   |   123271   |
# |   123271   |   123271   |
# |   123296   |   123296   |
# |   123361   |   123361   |
# |   123363   |   123363   |
# |   123425   |   123425   |
# |   123427   |   123427   |
# |   123429   |   123429   |
# |   123463   |   123463   |
# |   123490   |   123490   |
# |   123491   |   123491   |
# |   123584   |   123584   |
# |   123623   |   123623   |
# |   123651   |   123651   |
# |   123684   |   123684   |
# |   123685   |   123685   |
# |   123685   |   123685   |
# |   123712   |   123712   |
# |   123714   |   123714   |
# |   123719   |   123719   |
# |   123777   |   123777   |
# |   123809   |   123809   |
# |   123811   |   123811   |
# |   123813   |   123813   |
# |   123815   |   123815   |
# |   123843   |   123843   |
# |   123876   |   123876   |
# |   123877   |   123877   |
# |   123905   |   123905   |
# |   123943   |   123943   |
# |   123969   |   123969   |
# |   124004   |   124004   |
# |   124005   |   124005   |
# |   124067   |   124067   |
# |   124096   |   124096   |
# |   124163   |   124163   |
# |   124199   |   124199   |
# |   124256   |   124256   |
# |   124256   |   124256   |
# |   124258   |   124258   |
# |   124261   |   124261   |
# |   124261   |   124261   |
# |   124293   |   124293   |
# |   124356   |   124356   |
# |     7      |     7      |
# |     32     |     32     |
# |     33     |     33     |
# |     69     |     69     |
# |     71     |     71     |
# |    133     |    133     |
# |    198     |    198     |
# |    259     |    259     |
# |    260     |    260     |
# |    288     |    288     |
# |    353     |    353     |
# |    354     |    354     |
# |    420     |    420     |
# |    482     |    482     |
# |    485     |    485     |
# |    486     |    486     |
# |    512     |    512     |
# |    517     |    517     |
# |    548     |    548     |
# |    576     |    576     |
# |    576     |    576     |
# |    581     |    581     |
# |    614     |    614     |
# |    678     |    678     |
# |    679     |    679     |
# |    737     |    737     |
# |    771     |    771     |
# |    771     |    771     |
# |    772     |    772     |
# +------------+------------+
# Truncated to displaylimit of 100.

# %%
# %%sql
# SELECT
#   COUNT(o.o_orderkey) AS order_rows_count,
#   COUNT(l.l_orderkey) AS lineitem_rows_count
# FROM
#   orders o
#   FULL OUTER JOIN lineitem l ON o.o_orderkey = l.l_orderkey
#   AND o.o_orderdate BETWEEN l.l_shipdate - INTERVAL '5' DAY AND l.l_shipdate  + INTERVAL '5' DAY;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------------+---------------------+
# | order_rows_count | lineitem_rows_count |
# +------------------+---------------------+
# |     1519332      |       6001215       |
# +------------------+---------------------+

# %% [markdown]
# The output will have all the rows from orders that found at least one matching row from the lineitem table with the specified join condition (same o_orderkey and orderdate within ship date +/- 5 days) and all the rows from the lineitem table.
#
# We can also see that the number of rows from the orders table is 1,519,332 & from the lineitem table is 6,001,215.
#
# ## 5. Cross join: Get the cartesian product of all rows

# %%
# %%sql
# SELECT
#   n.n_name AS nation_c_name,
#   r.r_name AS region_c_name
# FROM
#   nation n
#   CROSS JOIN region r;
# Out:
# Running query in 'duckdb:///tpch.db'
# +----------------+---------------+
# | nation_c_name  | region_c_name |
# +----------------+---------------+
# |    ALGERIA     |     AFRICA    |
# |   ARGENTINA    |     AFRICA    |
# |     BRAZIL     |     AFRICA    |
# |     CANADA     |     AFRICA    |
# |     EGYPT      |     AFRICA    |
# |    ETHIOPIA    |     AFRICA    |
# |     FRANCE     |     AFRICA    |
# |    GERMANY     |     AFRICA    |
# |     INDIA      |     AFRICA    |
# |   INDONESIA    |     AFRICA    |
# |      IRAN      |     AFRICA    |
# |      IRAQ      |     AFRICA    |
# |     JAPAN      |     AFRICA    |
# |     JORDAN     |     AFRICA    |
# |     KENYA      |     AFRICA    |
# |    MOROCCO     |     AFRICA    |
# |   MOZAMBIQUE   |     AFRICA    |
# |      PERU      |     AFRICA    |
# |     CHINA      |     AFRICA    |
# |    ROMANIA     |     AFRICA    |
# |  SAUDI ARABIA  |     AFRICA    |
# |    VIETNAM     |     AFRICA    |
# |     RUSSIA     |     AFRICA    |
# | UNITED KINGDOM |     AFRICA    |
# | UNITED STATES  |     AFRICA    |
# |    ALGERIA     |    AMERICA    |
# |   ARGENTINA    |    AMERICA    |
# |     BRAZIL     |    AMERICA    |
# |     CANADA     |    AMERICA    |
# |     EGYPT      |    AMERICA    |
# |    ETHIOPIA    |    AMERICA    |
# |     FRANCE     |    AMERICA    |
# |    GERMANY     |    AMERICA    |
# |     INDIA      |    AMERICA    |
# |   INDONESIA    |    AMERICA    |
# |      IRAN      |    AMERICA    |
# |      IRAQ      |    AMERICA    |
# |     JAPAN      |    AMERICA    |
# |     JORDAN     |    AMERICA    |
# |     KENYA      |    AMERICA    |
# |    MOROCCO     |    AMERICA    |
# |   MOZAMBIQUE   |    AMERICA    |
# |      PERU      |    AMERICA    |
# |     CHINA      |    AMERICA    |
# |    ROMANIA     |    AMERICA    |
# |  SAUDI ARABIA  |    AMERICA    |
# |    VIETNAM     |    AMERICA    |
# |     RUSSIA     |    AMERICA    |
# | UNITED KINGDOM |    AMERICA    |
# | UNITED STATES  |    AMERICA    |
# |    ALGERIA     |      ASIA     |
# |   ARGENTINA    |      ASIA     |
# |     BRAZIL     |      ASIA     |
# |     CANADA     |      ASIA     |
# |     EGYPT      |      ASIA     |
# |    ETHIOPIA    |      ASIA     |
# |     FRANCE     |      ASIA     |
# |    GERMANY     |      ASIA     |
# |     INDIA      |      ASIA     |
# |   INDONESIA    |      ASIA     |
# |      IRAN      |      ASIA     |
# |      IRAQ      |      ASIA     |
# |     JAPAN      |      ASIA     |
# |     JORDAN     |      ASIA     |
# |     KENYA      |      ASIA     |
# |    MOROCCO     |      ASIA     |
# |   MOZAMBIQUE   |      ASIA     |
# |      PERU      |      ASIA     |
# |     CHINA      |      ASIA     |
# |    ROMANIA     |      ASIA     |
# |  SAUDI ARABIA  |      ASIA     |
# |    VIETNAM     |      ASIA     |
# |     RUSSIA     |      ASIA     |
# | UNITED KINGDOM |      ASIA     |
# | UNITED STATES  |      ASIA     |
# |    ALGERIA     |     EUROPE    |
# |   ARGENTINA    |     EUROPE    |
# |     BRAZIL     |     EUROPE    |
# |     CANADA     |     EUROPE    |
# |     EGYPT      |     EUROPE    |
# |    ETHIOPIA    |     EUROPE    |
# |     FRANCE     |     EUROPE    |
# |    GERMANY     |     EUROPE    |
# |     INDIA      |     EUROPE    |
# |   INDONESIA    |     EUROPE    |
# |      IRAN      |     EUROPE    |
# |      IRAQ      |     EUROPE    |
# |     JAPAN      |     EUROPE    |
# |     JORDAN     |     EUROPE    |
# |     KENYA      |     EUROPE    |
# |    MOROCCO     |     EUROPE    |
# |   MOZAMBIQUE   |     EUROPE    |
# |      PERU      |     EUROPE    |
# |     CHINA      |     EUROPE    |
# |    ROMANIA     |     EUROPE    |
# |  SAUDI ARABIA  |     EUROPE    |
# |    VIETNAM     |     EUROPE    |
# |     RUSSIA     |     EUROPE    |
# | UNITED KINGDOM |     EUROPE    |
# | UNITED STATES  |     EUROPE    |
# +----------------+---------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# The output will have every row of the nation joined with every row of the region. There are 25 nations and five regions, leading to 125 rows in our result from the cross-join.
#
# ![Joins](./images/im_27_1.png)
# ![Cross join](./images/im_27_2.png)
#
# There are cases where we will need to join a table with itself, called a SELF-join.
#
# **Example**:
#
# 1. For every customer order, get the order placed earlier in the same week (Sunday - Saturday, not the previous seven days). Only show customer orders that have at least one such order.

# %%
# %%sql
# SELECT
#   o1.o_custkey
# FROM
#   orders o1
#   JOIN orders o2 ON o1.o_custkey = o2.o_custkey
#   AND YEAR (o1.o_orderdate) = YEAR (o2.o_orderdate)
#   AND week (o1.o_orderdate) = week (o2.o_orderdate)
# WHERE
#   o1.o_orderkey != o2.o_orderkey;
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------+
# | o_custkey |
# +-----------+
# |   130057  |
# |    9220   |
# |   93385   |
# |   123823  |
# |   55126   |
# |   39907   |
# |   50417   |
# |   11704   |
# |   64754   |
# |   38299   |
# |   134617  |
# |   31696   |
# |    3478   |
# |   116326  |
# |   108556  |
# |   105941  |
# |   28924   |
# |   133400  |
# |    4306   |
# |   65312   |
# |   29749   |
# |   38071   |
# |   44923   |
# |   99505   |
# |   36427   |
# |   71026   |
# |   18637   |
# |   54376   |
# |   61123   |
# |   73696   |
# |   77266   |
# |    5663   |
# |   48157   |
# |    4243   |
# |   92359   |
# |   111901  |
# |   33227   |
# |   88393   |
# |   101821  |
# |   77359   |
# |   87323   |
# |   20941   |
# |   31168   |
# |   104617  |
# |   103651  |
# |   24016   |
# |   121615  |
# |   66976   |
# |   60367   |
# |   13177   |
# |   98308   |
# |   38041   |
# |   27061   |
# |   80107   |
# |   63397   |
# |   121156  |
# |   68575   |
# |   17677   |
# |   138236  |
# |   44716   |
# |   100228  |
# |   22951   |
# |   46567   |
# |   89615   |
# |    7828   |
# |   147937  |
# |   98675   |
# |   148414  |
# |   93235   |
# |   53362   |
# |   15377   |
# |   56425   |
# |   110447  |
# |   83902   |
# |   26557   |
# |   33688   |
# |   130417  |
# |   123316  |
# |   108506  |
# |   101696  |
# |   23443   |
# |   22462   |
# |   13658   |
# |   106831  |
# |   122150  |
# |   135751  |
# |   49093   |
# |   23536   |
# |   16915   |
# |   110323  |
# |   77701   |
# |   144865  |
# |    997    |
# |   83569   |
# |   79765   |
# |   38032   |
# |   84449   |
# |   22543   |
# |   60352   |
# |   35525   |
# +-----------+
# Truncated to displaylimit of 100.

# %% [markdown]
# Most analytical queries require calculating metrics that involve combining data from multiple rows. `GROUP BY` allows us to perform aggregate calculations on data from a set of rows grouped together based on values of specified column(s).
#
# **Example**:
#
# 1. Create a report that shows the number of orders per orderpriority segment.

# %%
# %%sql
# SELECT
#   o_orderpriority,
#   COUNT(*) AS num_orders
# FROM
#   orders
# GROUP BY
#   o_orderpriority;
# Out:
# Running query in 'duckdb:///tpch.db'
# +-----------------+------------+
# | o_orderpriority | num_orders |
# +-----------------+------------+
# |     1-URGENT    |   300343   |
# |      2-HIGH     |   300091   |
# |     3-MEDIUM    |   298723   |
# |      5-LOW      |   300589   |
# | 4-NOT SPECIFIED |   300254   |
# +-----------------+------------+

# %% [markdown]
# In the above query, we group the data by `orderpriority`, and the calculation `count(*)` will be applied to the rows having a specific `orderpriority` value. The output will consist of one row per unique value of `orderpriority` and the `count(*)` calculation.
#
# ![Group by](./images/im_28.png)
#
# The calculations allowed are typically SUM/MIN/MAX/AVG/COUNT. However, some databases have more complex aggregate functions; check your DB documentation.
#
# # [SUB QUERY] Use the result of a query within a query using sub-queries
#
# When we want to use the result of a query as a table in another query, we use subqueries. **Example**:
#
# 1. Create a report that shows the nation, how many items it supplied (by suppliers in that nation), and how many items it purchased (by customers in that nation).

# %%
# %%sql
# SELECT
#   n.n_name AS nation_c_name,
#   s.quantity AS supplied_items_quantity,
#   c.quantity AS purchased_items_quantity
# FROM
#   nation n
#   LEFT JOIN (
#     SELECT
#       n.n_nationkey,
#       SUM(l.l_quantity) AS quantity
#     FROM
#       lineitem l
#       JOIN supplier s ON l.l_suppkey = s.s_suppkey
#       JOIN nation n ON s.s_nationkey = n.n_nationkey
#     GROUP BY
#       n.n_nationkey
#   ) s ON n.n_nationkey = s.n_nationkey
#   LEFT JOIN (
#     SELECT
#       n.n_nationkey,
#       SUM(l.l_quantity) AS quantity
#     FROM
#       lineitem l
#       JOIN orders o ON l.l_orderkey = o.o_orderkey
#       JOIN customer c ON o.o_custkey = c.c_custkey
#       JOIN nation n ON c.c_nationkey = n.n_nationkey
#     GROUP BY
#       n.n_nationkey
#   ) c ON n.n_nationkey = c.n_nationkey;
# Out:
# Running query in 'duckdb:///tpch.db'
# +----------------+-------------------------+--------------------------+
# | nation_c_name  | supplied_items_quantity | purchased_items_quantity |
# +----------------+-------------------------+--------------------------+
# |    ALGERIA     |        6454691.00       |        6117618.00        |
# |   ARGENTINA    |        6339724.00       |        6087566.00        |
# |     BRAZIL     |        6085551.00       |        6149174.00        |
# |     CANADA     |        6296547.00       |        6168913.00        |
# |     EGYPT      |        6385468.00       |        6024134.00        |
# |    ETHIOPIA    |        5817697.00       |        6095241.00        |
# |     FRANCE     |        6141618.00       |        6289987.00        |
# |    GERMANY     |        6076474.00       |        6098776.00        |
# |     INDIA      |        6347392.00       |        6102406.00        |
# |   INDONESIA    |        6204759.00       |        6276420.00        |
# |      IRAN      |        5992033.00       |        6091271.00        |
# |      IRAQ      |        6678487.00       |        6003025.00        |
# |     JAPAN      |        5775308.00       |        6067924.00        |
# |     JORDAN     |        5539782.00       |        6230581.00        |
# |     KENYA      |        5753471.00       |        6002935.00        |
# |    MOROCCO     |        5691519.00       |        6060121.00        |
# |   MOZAMBIQUE   |        6253676.00       |        6243695.00        |
# |      PERU      |        6412494.00       |        6035782.00        |
# |     CHINA      |        6205793.00       |        6179322.00        |
# |    ROMANIA     |        6079467.00       |        6212841.00        |
# |  SAUDI ARABIA  |        6299506.00       |        5948921.00        |
# |    VIETNAM     |        6111369.00       |        6149667.00        |
# |     RUSSIA     |        6152008.00       |        6265778.00        |
# | UNITED KINGDOM |        5946859.00       |        6046145.00        |
# | UNITED STATES  |        6037102.00       |        6130552.00        |
# +----------------+-------------------------+--------------------------+

# %% [markdown]
# In the above query, we can see that there are two sub-queries, one to calculate the quantity supplied by a nation and the other to calculate the quantity purchased by the customers of a nation.
#
# # [CASE WHEN] Replicate IF.ELSE logic with CASE statements
#
# We can do conditional logic in the `SELECT ... FROM` part of our query, as shown below.

# %%
# %%sql
# SELECT
#     o_orderkey,
#     o_totalprice,
#     CASE
#         WHEN o_totalprice > 100000 THEN 'high'
#         WHEN o_totalprice BETWEEN 25000
#         AND 100000 THEN 'medium'
#         ELSE 'low'
#     END AS order_price_bucket
# FROM
#     orders;
# Out:
# Running query in 'duckdb:///tpch.db'
# +------------+--------------+--------------------+
# | o_orderkey | o_totalprice | order_price_bucket |
# +------------+--------------+--------------------+
# |     1      |  173665.47   |        high        |
# |     2      |   46929.18   |       medium       |
# |     3      |  193846.25   |        high        |
# |     4      |   32151.78   |       medium       |
# |     5      |  144659.20   |        high        |
# |     6      |   58749.59   |       medium       |
# |     7      |  252004.18   |        high        |
# |     32     |  208660.75   |        high        |
# |     33     |  163243.98   |        high        |
# |     34     |   58949.67   |       medium       |
# |     35     |  253724.56   |        high        |
# |     36     |   68289.96   |       medium       |
# |     37     |  206680.66   |        high        |
# |     38     |   82500.05   |       medium       |
# |     39     |  341734.47   |        high        |
# |     64     |   39414.99   |       medium       |
# |     65     |  110643.60   |        high        |
# |     66     |  103740.67   |        high        |
# |     67     |  169405.01   |        high        |
# |     68     |  330793.52   |        high        |
# |     69     |  197689.49   |        high        |
# |     70     |  113534.42   |        high        |
# |     71     |  276992.74   |        high        |
# |     96     |   68989.90   |       medium       |
# |     97     |  110512.84   |        high        |
# |     98     |   69168.33   |       medium       |
# |     99     |  112126.95   |        high        |
# |    100     |  187782.63   |        high        |
# |    101     |  124906.11   |        high        |
# |    102     |  164529.10   |        high        |
# |    103     |  126990.79   |        high        |
# |    128     |   66195.16   |       medium       |
# |    129     |  261013.14   |        high        |
# |    130     |  189484.12   |        high        |
# |    131     |  130464.09   |        high        |
# |    132     |  144947.21   |        high        |
# |    133     |  114663.57   |        high        |
# |    134     |  200354.30   |        high        |
# |    135     |  213713.99   |        high        |
# |    160     |  124132.06   |        high        |
# |    161     |   34439.93   |       medium       |
# |    162     |   2726.45    |        low         |
# |    163     |  202379.28   |        high        |
# |    164     |  301925.76   |        high        |
# |    165     |  188023.67   |        high        |
# |    166     |  154451.92   |        high        |
# |    167     |   71124.35   |       medium       |
# |    192     |  167668.42   |        high        |
# |    193     |   88699.17   |       medium       |
# |    194     |  176707.84   |        high        |
# |    195     |  191542.31   |        high        |
# |    196     |   47095.31   |       medium       |
# |    197     |  163700.57   |        high        |
# |    198     |  176189.31   |        high        |
# |    199     |  112986.49   |        high        |
# |    224     |  259960.36   |        high        |
# |    225     |  220441.09   |        high        |
# |    226     |  313134.62   |        high        |
# |    227     |   54880.58   |       medium       |
# |    228     |   2749.87    |        low         |
# |    229     |  213076.69   |        high        |
# |    230     |  171318.37   |        high        |
# |    231     |  191808.17   |        high        |
# |    256     |  130775.45   |        high        |
# |    257     |   8649.81    |        low         |
# |    258     |  294182.42   |        high        |
# |    259     |  123298.34   |        high        |
# |    260     |  272353.52   |        high        |
# |    261     |  319306.86   |        high        |
# |    262     |  143146.21   |        high        |
# |    263     |  149369.68   |        high        |
# |    288     |  266047.60   |        high        |
# |    289     |  211162.52   |        high        |
# |    290     |   99019.42   |       medium       |
# |    291     |  108550.11   |        high        |
# |    292     |   40637.14   |       medium       |
# |    293     |   58638.09   |       medium       |
# |    294     |   49457.90   |       medium       |
# |    295     |  130843.69   |        high        |
# |    320     |   53743.60   |       medium       |
# |    321     |   86823.16   |       medium       |
# |    322     |  205623.50   |        high        |
# |    323     |  119432.07   |        high        |
# |    324     |   38451.38   |       medium       |
# |    325     |  125113.94   |        high        |
# |    326     |  327413.14   |        high        |
# |    327     |   38488.56   |       medium       |
# |    352     |   28648.47   |       medium       |
# |    353     |  249710.43   |        high        |
# |    354     |  217160.72   |        high        |
# |    355     |   99516.75   |       medium       |
# |    356     |  209439.04   |        high        |
# |    357     |  157411.61   |        high        |
# |    358     |  354132.39   |        high        |
# |    359     |  239998.53   |        high        |
# |    384     |  166753.71   |        high        |
# |    385     |   54948.26   |       medium       |
# |    386     |  110216.57   |        high        |
# |    387     |  204546.39   |        high        |
# |    388     |  198800.71   |        high        |
# +------------+--------------+--------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# We can see how we display different values depending on the `totalprice` column. We can also use multiple criteria as our conditional criteria (e.g., totalprice > 100000 AND orderpriority = '2-HIGH').
#
# # [STANDARD FUNCTION] Use standard inbuilt DB functions for common String, Time, and Numeric data manipulation
#
# When processing data, more often than not, we will need to change values in columns; shown below are a few standard functions to be aware of:
#
# 1. **String functions**
#    1. **LENGTH** is used to calculate the length of a string. E.g., `SELECT LENGTH('hi');` will output 2.
#    2. **CONCAT** combines multiple string columns into one. E.g., `SELECT CONCAT(o_orderstatus, '-', o_orderpriority) FROM ORDERS LIMIT 5;` will concatenate the o_orderstatus and o_orderpriority columns with a dash in between them.
#    3. **SPLIT** is used to split a value into an array based on a given delimiter. E.g., `SELECT STRING_SPLIT(o_orderpriority, '-') FROM ORDERS LIMIT 5;` will output a column with arrays formed by splitting o_orderpriority values on `-`.
#    4. **SUBSTRING** is used to get a sub-string from a value, given the start and end character indices. E.g., `SELECT o_orderpriority, SUBSTRING(o_orderpriority, 1, 5) FROM orders LIMIT 5;` will get the first five (1 - 5) characters of the o_orderpriority column.
#    5. **TRIM** is used to remove empty spaces to the left and right of the value. E.g., `SELECT TRIM(' hi ');` will output `hi` without any spaces around it. LTRIM and RTRIM are similar but only remove spaces before and after the string, respectively.
# 2. **Date and Time functions**
#    1. **Adding and subtracting dates**: Is used to add and subtract periods; the format heavily depends on the DB. In DuckDB, `date_diff` accepts 3 parameters, the outputs unit (day, month, year), the datetime/date values a and b such that the output will be a - b. The `+ INTERVAL n UNIT(DAY/MONTH/YEAR)` adds the value (in specified units) to the timestamp value.
#       ```sql
#         -- Date and Time Functions
#         SELECT
#             date_diff('day', DATE '2022-10-01', DATE '2023-11-05') AS diff_in_days,
#             date_diff('month', DATE '2022-10-01', DATE '2023-11-05') AS diff_in_months,
#             date_diff('year', DATE '2022-10-01', DATE '2023-11-05') AS diff_in_years,
#             DATE '2022-10-01' + INTERVAL 400 DAY AS new_date;
#       ```
#     It will show the difference between the two dates in the specified period. We can also add/subtract an arbitrary period from a date/time column. E.g., `SELECT DATE '2022-11-05' + INTERVAL '10' DAY;` will show the output `2022-11-15` (try subtraction of dates).
#    2. **String <=> date/time conversions**: When we want to change the data type of a string to date/time, we can use the `DATE 'YYYY-MM-DD'` or `TIMESTAMP 'YYYY-MM-DD HH:mm:SS'` functions. But when the data is in a non-standard date/time format such as `MM/DD/YYYY`, we will need to specify the input structure; we do this using `strptime`, E.g., `SELECT strptime('11-05-2023', '%m-%d-%Y');`.
#
#    We can convert a timestamp/date into a string with the required format using `strftime`. E.g., `SELECT strftime(o_orderdate, '%Y-%m-01') AS first_month_date FROM orders LIMIT 5;` will map every o_orderdate to the first of their month.
#
#    See [this page](https://duckdb.org/docs/sql/functions/date) on how to set the proper date time format.
#    3. **Time frame functions (YEAR/MONTH/DAY)**:  When we want to extract specific periods from a date/time column, we can use these functions. E.g., `SELECT year(DATE '2023-11-05');` will return 2023. Similarly, we have month, day, hour, min, etc.
# 3. **Numeric**
#    1. **ROUND** is used to specify the number of digits allowed after the decimal point. E.g. `SELECT ROUND(100.102345, 2);`
#    2. **ABS** is used to get the absolute value of a given number. E.g. `SELECT ABS(-100), ABS(100);`
#    3. **Mathematical operations** these are +,-,*,/.
#    4. **Ceil/Floor** is used to get the next higher and most recent lower integers, given a decimal digit. E.g. `SELECT CEIL(100.1), FLOOR(100.1);`
